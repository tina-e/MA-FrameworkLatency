# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
PATH = "../data/211123_measurements"

# %%
files = os.listdir(PATH)
files = [x for x in files if 'csv' in x]
files
# Out:
# ['032aaf2e-a337-42b9-afbd-508c18d17dc6.csv',
#  '032e0632-2b16-4dad-92a8-12c16e18d17d.csv',
#  '048bdc5f-8070-4e7a-9493-f2007c624181.csv',
#  '095298b2-eb02-4bf2-9711-a06a2b4f64d6.csv',
#  '0d3891d7-855e-40a6-a6f7-351c04694326.csv',
#  '0d9d9fd5-15da-40c9-94da-dcaa03accba4.csv',
#  '117e57f2-cc71-411e-a5dc-a44e4a218ab3.csv',
#  '127b6464-7c38-4ca0-98d4-6197c6ef101c.csv',
#  '13afd4b2-6690-4089-ad59-60c0b706ee76.csv',
#  '13b7b275-cff8-47dd-85aa-a8fa4564e80c.csv',
#  '19143924-1db9-4d75-a181-bc4f6d701890.csv',
#  '1b39bf54-e312-47db-9088-9d001cac4ce2.csv',
#  '1cfa97c3-c405-44e6-98a6-ebf2307321a0.csv',
#  '1d78a812-7d31-434e-9553-c089feb7cb33.csv',
#  '1f08da34-62dc-4c3a-9244-b7c2516ca6f1.csv',
#  '242f38d0-1da9-4bed-b8da-14eb703b84b1.csv',
#  '250cf382-666a-4117-832c-577888824e9e.csv',
#  '25a60381-a336-4265-bf2d-4705693201f4.csv',
#  '27ebb578-6135-4bb0-b015-9e4584551728.csv',
#  '285f9cc7-de7d-4ec6-8bd5-afb3c683b9a8.csv',
#  '2abdde21-8feb-4e27-9741-739e6337e6ca.csv',
#  '2cd600d9-2cbf-4167-a125-c94dd2bd53c2.csv',
#  '2d4bf1b2-f0fe-4beb-8f1f-7d2c6e2f8536.csv',
#  '2d6af200-7c3a-447f-baff-aa9993883330.csv',
#  '306dbc65-8ef4-402b-b835-2b7c3f497a97.csv',
#  '373c1d63-67aa-4120-9ad1-2556ceeb0ad3.csv',
#  '3b0c9f3c-5122-4a7a-99c0-ed462a2cf820.csv',
#  '3dc60e30-4025-4296-9d81-363895cf4e65.csv',
#  '3e26d627-9860-468b-858a-bbbe7626dbae.csv',
#  '3e8b0baf-e45e-430d-abd0-1385f25cc2bd.csv',
#  '40b72e7a-0470-4403-9bed-0c36136d91e6.csv',
#  '43c0489e-8a72-4962-a8ee-673bc270460b.csv',
#  '45557a0f-7765-42ae-9840-ff8568a2404d.csv',
#  '4e7165a8-d4a5-4737-a7fc-8d3d66f99667.csv',
#  '507f55fc-ff42-4ed5-81e9-ecda532d24da.csv',
#  '5682a5de-53f2-4a28-913f-f76606ae62bd.csv',
#  '56e6ae43-29bd-43b0-85b0-81bf0d526d98.csv',
#  '574d04c6-2c77-4bfb-acc1-5e280799e032.csv',
#  '58c58580-f5b5-4d97-a211-a3ee463eddf5.csv',
#  '59ce0e6b-92b8-4816-8b2d-52a08532f536.csv',
#  '601d3a34-203c-45fc-a414-b1d40f306dc4.csv',
#  '60d9fc01-02e1-44e1-b1e6-4784be32e9ff.csv',
#  '6387abca-1fff-4b50-8927-ed5a42d5bb1c.csv',
#  '6697dcae-7464-45d7-a71d-4c139acf81d6.csv',
#  '67c82b53-ebd7-42ec-ac7a-b6ed7c75e691.csv',
#  '68c469b1-f469-42fe-b974-02077737b5b6.csv',
#  '6ab2917b-c6a2-4ef9-b1d5-3a567c19602e.csv',
#  '7254023d-06e8-48a1-b6e6-72511ce5eded.csv',
#  '75df5eb4-b718-4982-92ec-f8601840e409.csv',
#  '7848fe3d-d1df-445c-a096-568cd9b9f905.csv',
#  '7abda2c3-848f-4849-995b-025a4722f66f.csv',
#  '84b6481c-8c72-46fe-86b7-daa3d4ec88e9.csv',
#  '8c0c4cef-35d4-473d-980c-49c324afcb4a.csv',
#  '93dcfcbf-2d24-430a-9bfc-ef0eef51c9f7.csv',
#  '948a7dc9-f1b8-49ca-bd19-6432115afae7.csv',
#  '9eeab79f-6078-4a69-9570-53a1ee15d379.csv',
#  '9fdee20d-d02c-4616-9599-4d5ad8f11a71.csv',
#  'a7dad33d-ad4b-4316-aa93-baec4ceb23d4.csv',
#  'a7ed2fe5-e45b-4ace-a7a3-b9387560438c.csv',
#  'b3233144-300a-4666-b40b-cc6a16a3e1b5.csv',
#  'b594148a-3025-4034-a011-1531688b532d.csv',
#  'b5f49f66-a65e-4390-9772-7eb9d8c679a8.csv',
#  'b86c6afd-3ec3-4706-af6d-7898a9b2a2f8.csv',
#  'bb41daee-d44f-4317-a2dd-86e243a9f398.csv',
#  'c7374b64-e29d-463b-9ba8-b86349c281d0.csv',
#  'cc26abdb-4323-43df-afb2-e2b858117839.csv',
#  'cef4697c-da8f-4e7e-9bc6-a3ee6f1d6db8.csv',
#  'cfd3d5d0-a748-46f8-a11b-7ab1ccc28c7b.csv',
#  'd60c53b0-fa1f-4134-a6ad-242ae2d2d64c.csv',
#  'd7bc8a5e-10e4-4412-b21a-9b0669e447db.csv',
#  'dd2962f6-8015-490d-8252-d052ac3210f5.csv',
#  'e0ee4d93-f187-4d3d-b979-a246392181ee.csv',
#  'e2fe496d-afb7-404a-b66f-104ae6f1e9c2.csv',
#  'e36500e2-2c22-4ea6-a7f2-2f4f0e723a7e.csv',
#  'e4614d8e-2897-41d4-a3c7-1de323b231bd.csv',
#  'e4dd2e9d-78af-4fb9-b5eb-5c4431317c34.csv',
#  'eac6de7c-a71b-47da-9495-b55decb49790.csv',
#  'efcee09d-84b4-474c-99aa-76fad7b1c153.csv',
#  'f407922c-cab4-497e-bda6-945d9af1917b.csv',
#  'feb537db-3a10-4728-a38d-0293c98d2e9d.csv']

# %%
dataframes = []
for file in files:
    dataframes.append(pd.read_csv(f"{PATH}/{file}"))
data = pd.concat(dataframes)

# %% [markdown]
# ## End-to-end latencies with and without running framework tester
# ### Complexity: Default
#
# Almost the same -> no additional latency with framework tester

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running').set_title('end-to-end latencies with/without running fw-tester')
sns.stripplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(0, 90000)
for i in range(0, 20):
    plt.axhline(i*16.7*1000, color='red')
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_19720\2073509604.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running', dodge=True, color='black')

# %% [markdown]
# ### Complexity: Rects
#
# Also, no additional latency (even faster with running framework tester)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running').set_title('end-to-end latencies with/without running fw-tester')
sns.stripplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(0, 100000)
for i in range(0, 20):
    plt.axhline(i*16.7*1000, color='red')
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_19720\2673393491.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running', dodge=True, color='black')

# %% [markdown]
# ## Framework latency by framework
# ### Complexity: Default
#
# no results for pyqt5 and wxpython because of border

# %%
sns.boxplot(data=data[(data['complexity'] == 'default') & (data['fw_running'] == True)], x='framework', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[(data['complexity'] == 'default') & (data['fw_running'] == True)], x='framework', y='fw', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-1000, 30000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_19720\3975482710.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[(data['complexity'] == 'default') & (data['fw_running'] == True)], x='framework', y='fw', hue='program', dodge=True, color='black')
# (-1000.0, 30000.0)

# %% [markdown]
# ### Complexity: Rects

# %%
sns.boxplot(data=data[(data['complexity'] == 'rects') & (data['fw_running'] == True)], x='framework', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[(data['complexity'] == 'rects') & (data['fw_running'] == True)], x='framework', y='fw', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-1000, 100000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_19720\1268555585.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[(data['complexity'] == 'rects') & (data['fw_running'] == True)], x='framework', y='fw', hue='program', dodge=True, color='black')
# (-1000.0, 100000.0)

# %% [markdown]
# ### Framework latency by complexity

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-5000, 150000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_19720\3399512195.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True, color='black')
# (-5000.0, 150000.0)

# %% [markdown]
# ### Framework latency by framework

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-5000, 150000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_19720\2302280953.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True, color='black')
# (-5000.0, 150000.0)

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-5000, 150000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_19720\594577958.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='program', dodge=True, color='black')
# (-5000.0, 150000.0)

# %% [markdown]
# ## Difference (ete and fw) by program
# ### Complexity: Rects

# %%
sns.boxplot(data=data[(data['fw_running'] == True) & (data['complexity'] == 'rects')], x='framework', y='diff', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[(data['fw_running'] == True) & (data['complexity'] == 'rects')], x='framework', y='diff', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-80000, 80000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_19720\293663102.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[(data['fw_running'] == True) & (data['complexity'] == 'rects')], x='framework', y='diff', hue='program', dodge=True, color='black')
# (-80000.0, 80000.0)

# %% [markdown]
# ### Complexity: Default

# %%
sns.boxplot(data=data[(data['fw_running'] == True) & (data['complexity'] == 'default')], x='framework', y='diff', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[(data['fw_running'] == True) & (data['complexity'] == 'default')], x='framework', y='diff', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-80000, 80000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_19720\116234433.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[(data['fw_running'] == True) & (data['complexity'] == 'default')], x='framework', y='diff', hue='program', dodge=True, color='black')
# (-80000.0, 80000.0)

# %%
sns.boxplot(data=data[(data['fw_running'] == True)], x='framework', y='diff', hue='complexity', dodge=True).set_title('')
sns.stripplot(data=data[(data['fw_running'] == True)], x='framework', y='diff', hue='complexity', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-80000, 80000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_19720\2894130567.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[(data['fw_running'] == True)], x='framework', y='diff', hue='complexity', dodge=True, color='black')
# (-80000.0, 80000.0)
