# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.transforms as transforms
import seaborn as sns
import math
import os

# %%
PATH = "../data/2112_python_readers"
files = os.listdir(PATH)
files = [x for x in files if 'csv' in x]

# %%
file_data = []
file_data_clean = []
diff_means = []
diff_means_clean = []
for file in files:
    data_in = pd.read_csv(f"{PATH}/{file}")
    file_data.append(data_in)
    mean = data_in.query("fw != -1")['diff'].mean()
    if not math.isnan(mean):
        diff_means.append(mean)

    data_in_clean = data_in[data_in['diff'] > 5]
    file_data_clean.append(data_in_clean)
    mean_clean = data_in_clean.query("fw != -1")['diff'].mean()
    if not math.isnan(mean_clean):
        diff_means_clean.append(mean_clean)

# %%
data = pd.concat(file_data)
data_clean = pd.concat(file_data_clean)

# %% [markdown]
# # E2E Latency

# %%
fig, axes = plt.subplots(2, 1, figsize=(15, 7), sharex=True, sharey=True)
fig.suptitle("E2E Latency")

sns.boxplot(ax=axes[0], data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running')
sns.stripplot(ax=axes[0], data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
axes[0].set_title("default")

sns.boxplot(ax=axes[1], data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running')
sns.stripplot(ax=axes[1], data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
axes[1].set_title("rects")
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\2361163194.py:5: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[0], data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\2361163194.py:9: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[1], data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
# Text(0.5, 1.0, 'rects')

# %%
FRAMEWORK = 'SDL2_OPENGL'
fig, axes = plt.subplots(2, 1, figsize=(15, 7), sharex=True, sharey=True)
fig.suptitle(f"E2E Latency for {FRAMEWORK}")

sns.boxplot(ax=axes[0], data=data[((data['complexity'] == 'default') & (data['framework'] == FRAMEWORK))], x='program', y='ete', hue='fw_running')
sns.stripplot(ax=axes[0], data=data[((data['complexity'] == 'default') & (data['framework'] == FRAMEWORK))], x='program', y='ete', hue='fw_running', dodge=True, color='black')
axes[0].set_title("default")

sns.boxplot(ax=axes[1], data=data[((data['complexity'] == 'rects') & (data['framework'] == FRAMEWORK))], x='program', y='ete', hue='fw_running')
sns.stripplot(ax=axes[1], data=data[((data['complexity'] == 'rects') & (data['framework'] == FRAMEWORK))], x='program', y='ete', hue='fw_running', dodge=True, color='black')
axes[1].set_title("rects")
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\3103412670.py:6: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[0], data=data[((data['complexity'] == 'default') & (data['framework'] == FRAMEWORK))], x='program', y='ete', hue='fw_running', dodge=True, color='black')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\3103412670.py:10: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[1], data=data[((data['complexity'] == 'rects') & (data['framework'] == FRAMEWORK))], x='program', y='ete', hue='fw_running', dodge=True, color='black')
# Text(0.5, 1.0, 'rects')

# %% [markdown]
# # Framework Latency

# %%
data_fw_running = data[data['fw_running'] == True]
data_fw_running_clean = data_clean[data_clean['fw_running'] == True]

# %%
# sns.set(rc={'figure.figsize':(15, 5)})
# sns.boxplot(data=data_fw_running, x='framework_complexity', y='fw', hue='program', dodge=True).set_title("Framework Latency")
# plot = sns.stripplot(data=data_fw_running, x='framework_complexity', y='fw', hue='program', dodge=True, color='black')

# plot.set_xticklabels(plot.get_xticklabels(), rotation=90)

# %%
# READER = 'getpixel'
# sns.set(rc={'figure.figsize':(15, 5)})
# sns.boxplot(data=data_fw_running[data_fw_running['program'] == READER], x='framework', y='fw', hue='complexity', dodge=True).set_title(f"Framework Latency for {READER}")
# plot = sns.stripplot(data=data_fw_running[data_fw_running['program'] == READER], x='framework', y='fw', hue='complexity', dodge=True, color='black')
# plot.set_xticklabels(plot.get_xticklabels(), rotation=90)

# %%
fig, axes = plt.subplots(3, 1, figsize=(15, 7), sharex=True, sharey=True)
fig.suptitle(f"Framework Latency by complexity")

sns.boxplot(ax=axes[0], data=data_fw_running[data_fw_running['complexity'] == 'default'], x='framework', y='fw', hue='program', dodge=True)
sns.stripplot(ax=axes[0], data=data_fw_running[data_fw_running['complexity'] == 'default'], x='framework', y='fw', hue='program', dodge=True, color='black')
axes[0].set_title("default")

sns.boxplot(ax=axes[1], data=data_fw_running[data_fw_running['complexity'] == 'rects'], x='framework', y='fw', hue='program', dodge=True)
sns.stripplot(ax=axes[1], data=data_fw_running[data_fw_running['complexity'] == 'rects'], x='framework', y='fw', hue='program', dodge=True, color='black')
axes[1].set_title("rects")

offset = lambda p: transforms.ScaledTranslation(p/72.,0, plt.gcf().dpi_scale_trans)
trans = plt.gca().transData
sns.stripplot(ax=axes[2], data=data_fw_running[data_fw_running['complexity'] == 'default'], x='framework', y='fw', hue='program', dodge=True, color='blue')
sns.stripplot(ax=axes[2], data=data_fw_running[data_fw_running['complexity'] == 'rects'], x='framework', y='fw', hue='program', dodge=True, color='red', transform=offset(0.05)+trans)
axes[2].set_title("combined")

axes[2].set_xticklabels(axes[2].get_xticklabels(), rotation=90)
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\2448222163.py:5: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[0], data=data_fw_running[data_fw_running['complexity'] == 'default'], x='framework', y='fw', hue='program', dodge=True, color='black')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\2448222163.py:9: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[1], data=data_fw_running[data_fw_running['complexity'] == 'rects'], x='framework', y='fw', hue='program', dodge=True, color='black')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\2448222163.py:14: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:blue'` for the same effect.
#
#   sns.stripplot(ax=axes[2], data=data_fw_running[data_fw_running['complexity'] == 'default'], x='framework', y='fw', hue='program', dodge=True, color='blue')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\2448222163.py:15: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.stripplot(ax=axes[2], data=data_fw_running[data_fw_running['complexity'] == 'rects'], x='framework', y='fw', hue='program', dodge=True, color='red', transform=offset(0.05)+trans)
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\2448222163.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[2].set_xticklabels(axes[2].get_xticklabels(), rotation=90)
# [Text(0, 0, 'GLUT'),
#  Text(1, 0, 'Java2D'),
#  Text(2, 0, 'JavaSwing'),
#  Text(3, 0, 'pygame'),
#  Text(4, 0, 'pyglet'),
#  Text(5, 0, 'pyqt5'),
#  Text(6, 0, 'pyqt6'),
#  Text(7, 0, 'SDL2_OpenGLES'),
#  Text(8, 0, 'SDL2_OPENGL'),
#  Text(9, 0, 'SDL2_Software'),
#  Text(10, 0, 'tkinter'),
#  Text(11, 0, 'wxpython')]

# %%
fig, axes = plt.subplots(3, 1, figsize=(15, 7), sharex=True, sharey=True)
fig.suptitle(f"Framework Latency by complexity - bereinigt")

sns.boxplot(ax=axes[0], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'default'], x='framework', y='fw', hue='program', dodge=True)
sns.stripplot(ax=axes[0], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'default'], x='framework', y='fw', hue='program', dodge=True, color='black')
axes[0].set_title("default")

sns.boxplot(ax=axes[1], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'rects'], x='framework', y='fw', hue='program', dodge=True)
sns.stripplot(ax=axes[1], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'rects'], x='framework', y='fw', hue='program', dodge=True, color='black')
axes[1].set_title("rects")

offset = lambda p: transforms.ScaledTranslation(p/72.,0, plt.gcf().dpi_scale_trans)
trans = plt.gca().transData
sns.stripplot(ax=axes[2], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'default'], x='framework', y='fw', hue='program', dodge=True, color='blue')
sns.stripplot(ax=axes[2], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'rects'], x='framework', y='fw', hue='program', dodge=True, color='red', transform=offset(0.05)+trans)
axes[2].set_title("combined")

axes[2].set_xticklabels(axes[2].get_xticklabels(), rotation=90)
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\3128098735.py:5: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[0], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'default'], x='framework', y='fw', hue='program', dodge=True, color='black')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\3128098735.py:9: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[1], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'rects'], x='framework', y='fw', hue='program', dodge=True, color='black')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\3128098735.py:14: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:blue'` for the same effect.
#
#   sns.stripplot(ax=axes[2], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'default'], x='framework', y='fw', hue='program', dodge=True, color='blue')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\3128098735.py:15: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.stripplot(ax=axes[2], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'rects'], x='framework', y='fw', hue='program', dodge=True, color='red', transform=offset(0.05)+trans)
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\3128098735.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[2].set_xticklabels(axes[2].get_xticklabels(), rotation=90)
# [Text(0, 0, 'GLUT'),
#  Text(1, 0, 'Java2D'),
#  Text(2, 0, 'JavaSwing'),
#  Text(3, 0, 'pygame'),
#  Text(4, 0, 'pyglet'),
#  Text(5, 0, 'pyqt5'),
#  Text(6, 0, 'pyqt6'),
#  Text(7, 0, 'SDL2_OpenGLES'),
#  Text(8, 0, 'SDL2_OPENGL'),
#  Text(9, 0, 'SDL2_Software'),
#  Text(10, 0, 'tkinter'),
#  Text(11, 0, 'wxpython')]

# %%
# FRAMEWORK = 'SDL2_OPENGL'
# fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharex=True, sharey=True)
# fig.suptitle(f"Framework Latency for {FRAMEWORK}")

# sns.boxplot(ax=axes[0], data=data_fw_running[((data_fw_running['complexity'] == 'default') & (data_fw_running['framework'] == FRAMEWORK))], x='framework', y='fw', hue='program', dodge=True)
# sns.stripplot(ax=axes[0], data=data_fw_running[((data_fw_running['complexity'] == 'default') & (data_fw_running['framework'] == FRAMEWORK))], x='framework', y='fw', hue='program', dodge=True, color='black')
# axes[0].set_title("default")

# sns.boxplot(ax=axes[1], data=data_fw_running[((data_fw_running['complexity'] == 'rects') & (data_fw_running['framework'] == FRAMEWORK))], x='framework', y='fw', hue='program', dodge=True)
# sns.stripplot(ax=axes[1], data=data_fw_running[((data_fw_running['complexity'] == 'rects') & (data_fw_running['framework'] == FRAMEWORK))], x='framework', y='fw', hue='program', dodge=True, color='black')
# axes[1].set_title("rects")

# %% [markdown]
# # Difference

# %%
fig, axes = plt.subplots(3, 1, figsize=(15, 10), sharex=True, sharey=True)
fig.suptitle("Difference (E2E - FW)")

sns.boxplot(ax=axes[0], data=data_fw_running[data_fw_running['complexity'] == 'default'], x='framework', y='diff', hue='program', dodge=True)
sns.stripplot(ax=axes[0], data=data_fw_running[data_fw_running['complexity'] == 'default'], x='framework', y='diff', hue='program', dodge=True, color='black')
axes[0].set_title("default")
plt.axhline(0, color='grey')

sns.boxplot(ax=axes[1], data=data_fw_running[data_fw_running['complexity'] == 'rects'], x='framework', y='diff', hue='program', dodge=True)
sns.stripplot(ax=axes[1], data=data_fw_running[data_fw_running['complexity'] == 'rects'], x='framework', y='diff', hue='program', dodge=True, color='black')
axes[1].set_title("rects")
plt.axhline(0, color='grey')

offset = lambda p: transforms.ScaledTranslation(p/72.,0, plt.gcf().dpi_scale_trans)
trans = plt.gca().transData
sns.stripplot(ax=axes[2], data=data_fw_running[data_fw_running['complexity'] == 'default'], x='framework', y='diff', hue='program', dodge=True, color='blue')
sns.stripplot(ax=axes[2], data=data_fw_running[data_fw_running['complexity'] == 'rects'], x='framework', y='diff', hue='program', dodge=True, color='red', transform=offset(0.05)+trans)
axes[2].set_title("combined")
plt.axhline(0, color='grey')

agg_mean = round(np.mean(diff_means), 1)
plt.axhline(agg_mean, color='black')

#axes[3].set_ylim(-10000, 50000)

axes[2].set_xticklabels(axes[2].get_xticklabels(), rotation=90)
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\411791743.py:5: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[0], data=data_fw_running[data_fw_running['complexity'] == 'default'], x='framework', y='diff', hue='program', dodge=True, color='black')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\411791743.py:10: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[1], data=data_fw_running[data_fw_running['complexity'] == 'rects'], x='framework', y='diff', hue='program', dodge=True, color='black')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\411791743.py:16: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:blue'` for the same effect.
#
#   sns.stripplot(ax=axes[2], data=data_fw_running[data_fw_running['complexity'] == 'default'], x='framework', y='diff', hue='program', dodge=True, color='blue')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\411791743.py:17: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.stripplot(ax=axes[2], data=data_fw_running[data_fw_running['complexity'] == 'rects'], x='framework', y='diff', hue='program', dodge=True, color='red', transform=offset(0.05)+trans)
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\411791743.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[2].set_xticklabels(axes[2].get_xticklabels(), rotation=90)
# [Text(0, 0, 'GLUT'),
#  Text(1, 0, 'Java2D'),
#  Text(2, 0, 'JavaSwing'),
#  Text(3, 0, 'pygame'),
#  Text(4, 0, 'pyglet'),
#  Text(5, 0, 'pyqt5'),
#  Text(6, 0, 'pyqt6'),
#  Text(7, 0, 'SDL2_OpenGLES'),
#  Text(8, 0, 'SDL2_OPENGL'),
#  Text(9, 0, 'SDL2_Software'),
#  Text(10, 0, 'tkinter'),
#  Text(11, 0, 'wxpython')]

# %%
fig, axes = plt.subplots(3, 1, figsize=(15, 10), sharex=True, sharey=True)
fig.suptitle("Difference (E2E - FW) - bereinigt")

sns.boxplot(ax=axes[0], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'default'], x='framework', y='diff', hue='program', dodge=True)
sns.stripplot(ax=axes[0], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'default'], x='framework', y='diff', hue='program', dodge=True, color='black')
axes[0].set_title("default")
plt.axhline(0, color='grey')

sns.boxplot(ax=axes[1], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'rects'], x='framework', y='diff', hue='program', dodge=True)
sns.stripplot(ax=axes[1], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'rects'], x='framework', y='diff', hue='program', dodge=True, color='black')
axes[1].set_title("rects")
plt.axhline(0, color='grey')

offset = lambda p: transforms.ScaledTranslation(p/72.,0, plt.gcf().dpi_scale_trans)
trans = plt.gca().transData
sns.stripplot(ax=axes[2], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'default'], x='framework', y='diff', hue='program', dodge=True, color='blue')
sns.stripplot(ax=axes[2], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'rects'], x='framework', y='diff', hue='program', dodge=True, color='red', transform=offset(0.05)+trans)
axes[2].set_title("combined")
plt.axhline(0, color='grey')

agg_mean_clean = round(np.mean(diff_means_clean), 1)
plt.axhline(agg_mean_clean, color='black')

#axes[2].set_ylim(-10000, 50000)

axes[2].set_xticklabels(axes[2].get_xticklabels(), rotation=90)
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\691941631.py:5: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[0], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'default'], x='framework', y='diff', hue='program', dodge=True, color='black')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\691941631.py:10: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[1], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'rects'], x='framework', y='diff', hue='program', dodge=True, color='black')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\691941631.py:16: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:blue'` for the same effect.
#
#   sns.stripplot(ax=axes[2], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'default'], x='framework', y='diff', hue='program', dodge=True, color='blue')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\691941631.py:17: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.stripplot(ax=axes[2], data=data_fw_running_clean[data_fw_running_clean['complexity'] == 'rects'], x='framework', y='diff', hue='program', dodge=True, color='red', transform=offset(0.05)+trans)
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\691941631.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[2].set_xticklabels(axes[2].get_xticklabels(), rotation=90)
# [Text(0, 0, 'GLUT'),
#  Text(1, 0, 'Java2D'),
#  Text(2, 0, 'JavaSwing'),
#  Text(3, 0, 'pygame'),
#  Text(4, 0, 'pyglet'),
#  Text(5, 0, 'pyqt5'),
#  Text(6, 0, 'pyqt6'),
#  Text(7, 0, 'SDL2_OpenGLES'),
#  Text(8, 0, 'SDL2_OPENGL'),
#  Text(9, 0, 'SDL2_Software'),
#  Text(10, 0, 'tkinter'),
#  Text(11, 0, 'wxpython')]

# %% [markdown]
# # Combined

# %%
FRAMEWORK = 'GLUT'
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharex=True, sharey=True)
fig.suptitle(f"Latency for {FRAMEWORK}")

sns.boxplot(ax=axes[0], data=data_fw_running[data_fw_running['framework'] == FRAMEWORK], x='framework_complexity', y='ete', hue='program', dodge=True)
sns.stripplot(ax=axes[0], data=data_fw_running[data_fw_running['framework'] == FRAMEWORK], x='framework_complexity', y='ete', hue='program', dodge=True, color='black')
axes[0].set_title("ent-to-end")

sns.boxplot(ax=axes[1], data=data_fw_running[data_fw_running['framework'] == FRAMEWORK], x='framework_complexity', y='fw', hue='program', dodge=True)
sns.stripplot(ax=axes[1], data=data_fw_running[data_fw_running['framework'] == FRAMEWORK], x='framework_complexity', y='fw', hue='program', dodge=True, color='black')
axes[1].set_title("framework")

sns.boxplot(ax=axes[2], data=data_fw_running[data_fw_running['framework'] == FRAMEWORK], x='framework_complexity', y='diff', hue='program', dodge=True)
sns.stripplot(ax=axes[2], data=data_fw_running[data_fw_running['framework'] == FRAMEWORK], x='framework_complexity', y='diff', hue='program', dodge=True, color='black')
axes[2].set_title("diff")

axes[2].set_ylim(-20000, 40000)
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\2943028267.py:6: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[0], data=data_fw_running[data_fw_running['framework'] == FRAMEWORK], x='framework_complexity', y='ete', hue='program', dodge=True, color='black')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\2943028267.py:10: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[1], data=data_fw_running[data_fw_running['framework'] == FRAMEWORK], x='framework_complexity', y='fw', hue='program', dodge=True, color='black')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\2943028267.py:14: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[2], data=data_fw_running[data_fw_running['framework'] == FRAMEWORK], x='framework_complexity', y='diff', hue='program', dodge=True, color='black')
# (-20000.0, 40000.0)

# %%
FRAMEWORK = 'GLUT'
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharex=True, sharey=True)
fig.suptitle(f"Latency for {FRAMEWORK} - bereinigt")

sns.boxplot(ax=axes[0], data=data_fw_running_clean[data_fw_running_clean['framework'] == FRAMEWORK], x='framework_complexity', y='ete', hue='program', dodge=True)
sns.stripplot(ax=axes[0], data=data_fw_running_clean[data_fw_running_clean['framework'] == FRAMEWORK], x='framework_complexity', y='ete', hue='program', dodge=True, color='black')
axes[0].set_title("ent-to-end")

sns.boxplot(ax=axes[1], data=data_fw_running_clean[data_fw_running_clean['framework'] == FRAMEWORK], x='framework_complexity', y='fw', hue='program', dodge=True)
sns.stripplot(ax=axes[1], data=data_fw_running_clean[data_fw_running_clean['framework'] == FRAMEWORK], x='framework_complexity', y='fw', hue='program', dodge=True, color='black')
axes[1].set_title("framework")

sns.boxplot(ax=axes[2], data=data_fw_running_clean[data_fw_running_clean['framework'] == FRAMEWORK], x='framework_complexity', y='diff', hue='program', dodge=True)
sns.stripplot(ax=axes[2], data=data_fw_running_clean[data_fw_running_clean['framework'] == FRAMEWORK], x='framework_complexity', y='diff', hue='program', dodge=True, color='black')
axes[2].set_title("diff")

axes[2].set_ylim(-20000, 40000)
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\4204324868.py:6: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[0], data=data_fw_running_clean[data_fw_running_clean['framework'] == FRAMEWORK], x='framework_complexity', y='ete', hue='program', dodge=True, color='black')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\4204324868.py:10: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[1], data=data_fw_running_clean[data_fw_running_clean['framework'] == FRAMEWORK], x='framework_complexity', y='fw', hue='program', dodge=True, color='black')
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_17068\4204324868.py:14: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(ax=axes[2], data=data_fw_running_clean[data_fw_running_clean['framework'] == FRAMEWORK], x='framework_complexity', y='diff', hue='program', dodge=True, color='black')
# (-20000.0, 40000.0)
