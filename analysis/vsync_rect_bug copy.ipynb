# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# vsync on, rects not in corner

# %%
PATH = "../data/vsync_off/221123_measurements_no_vsync"

# %%
files = os.listdir(PATH)
files = [x for x in files if 'csv' in x]
files
# Out:
# ['Java2D_default_False_bitblt_c722f456-6fdf-495a-baeb-4069fecfa2db.csv',
#  'Java2D_default_False_getdbits_c380935b-58ac-4f0f-9def-4b897d22c008.csv',
#  'Java2D_default_False_getpixel_8fa50564-a26b-42d2-bf50-cc09ab125223.csv',
#  'Java2D_default_False_windup_python_f7d2123e-90ca-44b3-90d9-b05d93964824.csv',
#  'Java2D_default_True_bitblt_2032538f-24c7-4d7c-823d-bff40f7a4acd.csv',
#  'Java2D_default_True_getdbits_f86766e7-9338-4b33-a4b6-01f9e9f3e99e.csv',
#  'Java2D_default_True_getpixel_8d102e0c-fd9c-4b23-9d95-c66f8993488a.csv',
#  'Java2D_default_True_windup_python_81512a35-bdef-4236-9db9-c514b6f1076f.csv',
#  'Java2D_rects_False_bitblt_81950ffd-89e3-49f8-8e8d-ab2e7955e6a6.csv',
#  'Java2D_rects_False_getdbits_2cfe5682-56d6-45fd-b727-99b526638891.csv',
#  'Java2D_rects_False_getpixel_501bfd0f-f098-4994-a259-17ef4b92f36f.csv',
#  'Java2D_rects_False_windup_python_7a7f2cf9-9dea-4592-a7c6-1b129cf46774.csv',
#  'Java2D_rects_True_bitblt_b5a9ad77-162e-490f-b456-e7edfd3ff1a1.csv',
#  'Java2D_rects_True_getdbits_56064e4b-867c-484e-8406-ef8bf61defc0.csv',
#  'Java2D_rects_True_getpixel_7a923265-2c2a-4208-aad4-b27fc41f5e8a.csv',
#  'Java2D_rects_True_windup_python_dcd33796-ce3b-4a3c-ae94-b954ca20318f.csv',
#  'JavaSwing_default_False_bitblt_a23edc32-d341-4d73-b979-c83c7a536253.csv',
#  'JavaSwing_default_False_getdbits_cf65f64d-02ff-4fa2-9a7d-8ba21bfd88b8.csv',
#  'JavaSwing_default_False_getpixel_a5a69e74-330e-4d56-a14f-348252f89b92.csv',
#  'JavaSwing_default_False_windup_python_c6c416fc-d4e5-4133-a8fb-07902fce5842.csv',
#  'JavaSwing_default_True_bitblt_3b84cb25-8520-4b61-8a3c-cbaf0e23ea9e.csv',
#  'JavaSwing_default_True_getdbits_770c9a7a-c496-4c0d-9345-3b7f8d8037e3.csv',
#  'JavaSwing_default_True_getpixel_b124a1ce-ab58-460b-b103-2b01c2a52436.csv',
#  'JavaSwing_default_True_windup_python_b433a375-ca64-4e79-a0e0-f00d7a148752.csv',
#  'JavaSwing_rects_False_bitblt_2b63c557-92bd-40fc-9b16-c72f65f559d1.csv',
#  'JavaSwing_rects_False_getdbits_d55502c3-87aa-4a62-85d7-42d6bb8f3048.csv',
#  'JavaSwing_rects_False_getpixel_aede7149-b73a-4299-af8c-7125a6c0f0b6.csv',
#  'JavaSwing_rects_False_windup_python_732634c3-c892-48ed-b1d8-86e3a0542811.csv',
#  'JavaSwing_rects_True_bitblt_3eb354c8-eb5b-4c3e-8e22-2aa731b3ce2a.csv',
#  'JavaSwing_rects_True_getdbits_d6087f20-b2d1-4b69-b3d6-245b1db3031d.csv',
#  'JavaSwing_rects_True_getpixel_0ea3240f-522a-4dac-bb82-d5e7cdd4d5a4.csv',
#  'JavaSwing_rects_True_windup_python_04c37800-4658-4445-b07e-76b05e6aade3.csv',
#  'pygame_default_False_bitblt_5502d071-a768-499f-8dc6-29a2700baad7.csv',
#  'pygame_default_False_getdbits_85407988-a30a-4421-85c9-e642522600d5.csv',
#  'pygame_default_False_getpixel_719364c1-cf34-4f38-a6e6-571e67f2909d.csv',
#  'pygame_default_False_windup_python_bed58e43-fa39-489f-83db-28d91f9daf59.csv',
#  'pygame_default_True_bitblt_3cbce652-c428-4a89-b9b3-d514809ce60f.csv',
#  'pygame_default_True_getdbits_126905b8-9c91-4f8d-b2f0-8f746b2c7492.csv',
#  'pygame_default_True_getpixel_34413810-488c-45db-8af3-fed112171d0e.csv',
#  'pygame_default_True_windup_python_a0bb82eb-b931-4a31-acf5-a64513e25469.csv',
#  'pygame_rects_False_bitblt_86378bb3-9b50-418b-ae4a-1317028f55d6.csv',
#  'pygame_rects_False_getdbits_d63475d7-ef71-4063-a2cb-37d3f8747e0f.csv',
#  'pygame_rects_False_getpixel_bc5217a8-440b-419f-89da-4c9366a20ca0.csv',
#  'pygame_rects_False_windup_python_a2cca615-43f5-40d5-98a7-b4ab005c2cbf.csv',
#  'pygame_rects_True_bitblt_f60bcaa4-03a7-4fff-8a1e-6abb836e517b.csv',
#  'pygame_rects_True_getdbits_0160e00c-e7e9-474a-afcf-840c77d0e957.csv',
#  'pygame_rects_True_getpixel_0fc60ea5-983a-445d-a9aa-06a6af52066e.csv',
#  'pygame_rects_True_windup_python_719b88e5-f0e7-4734-895c-cc5f1bb5ae88.csv',
#  'pyqt5_default_False_bitblt_d27c1043-23e8-40a5-8cd6-c232c615d429.csv',
#  'pyqt5_default_False_getdbits_5dd03ba1-f064-4920-b672-666e08a35dd8.csv',
#  'pyqt5_default_False_getpixel_92c594e5-fa59-4f6b-a816-dfaf56b9608c.csv',
#  'pyqt5_default_False_windup_python_a14eb86f-e6ce-4980-bcc9-9e03f788ca2a.csv',
#  'pyqt5_default_True_bitblt_e626fed5-ec53-4a8d-b11f-6367227356d6.csv',
#  'pyqt5_default_True_getdbits_d5e344de-2653-4583-b453-a144316ebf47.csv',
#  'pyqt5_default_True_getpixel_7bd5d1ee-33d9-4695-a4eb-2c5d3cd746f5.csv',
#  'pyqt5_default_True_windup_python_b6d20d97-18cf-49c9-ba7a-97f0d95d65c9.csv',
#  'pyqt5_rects_False_bitblt_69142f76-dfe2-4c1e-b190-6d0aad93119c.csv',
#  'pyqt5_rects_False_getdbits_ff2e9c98-9345-4cd7-860c-a3ff07e40467.csv',
#  'pyqt5_rects_False_getpixel_35aed898-c844-4fdc-a74f-e8433072c37a.csv',
#  'pyqt5_rects_False_windup_python_900e757d-da0d-4aef-ba8e-add3faa31589.csv',
#  'pyqt5_rects_True_bitblt_8846806c-de90-4f94-b502-064b136f8a8f.csv',
#  'pyqt5_rects_True_getdbits_68c8fc6f-53f4-4826-a393-337fc47507b9.csv',
#  'pyqt5_rects_True_getpixel_6f828954-0e84-49b1-bce8-e5728067a63a.csv',
#  'pyqt5_rects_True_windup_python_87aa007d-cdda-475a-894a-a2284c8e1335.csv',
#  'SDL2_OpenGLES_default_False_bitblt_75812861-6dfb-4f56-99f0-4ccf9a9cc771.csv',
#  'SDL2_OpenGLES_default_False_getdbits_245cd21b-c4d0-4747-a988-e65f442bcdc8.csv',
#  'SDL2_OpenGLES_default_False_getpixel_7e14273f-2ce9-48df-b3d9-6ebf295eb257.csv',
#  'SDL2_OpenGLES_default_False_windup_python_00869cbd-73d9-46c0-873f-a575e641e47e.csv',
#  'SDL2_OpenGLES_default_True_bitblt_fdeaa7c0-c37a-40ad-9077-5d67668354ca.csv',
#  'SDL2_OpenGLES_default_True_getdbits_52fc2d2f-5b23-4d94-998f-3bba434ab2cb.csv',
#  'SDL2_OpenGLES_default_True_getpixel_308b604e-38cb-4a2b-8fe1-f9f5eb15950d.csv',
#  'SDL2_OpenGLES_default_True_windup_python_ead3b1b2-6b37-47aa-9a07-379ba4a553a0.csv',
#  'SDL2_OpenGLES_rects_False_bitblt_f82c6617-e097-42fd-aea3-2d187123b4b6.csv',
#  'SDL2_OpenGLES_rects_False_getdbits_74ceb3e3-376e-4ae3-a3ec-676e402cf6da.csv',
#  'SDL2_OpenGLES_rects_False_getpixel_2d59fda0-eb9e-407c-b775-c460d5649efa.csv',
#  'SDL2_OpenGLES_rects_False_windup_python_9a1f3510-5685-428f-bafb-25c8afc34cc0.csv',
#  'SDL2_OpenGLES_rects_True_bitblt_ffe0deeb-872a-4808-aaf8-6ff4730bc966.csv',
#  'SDL2_OpenGLES_rects_True_getdbits_51acf0eb-f348-4a0d-8ce5-619aabde3067.csv',
#  'SDL2_OpenGLES_rects_True_getpixel_ffda97a5-90ec-4174-a583-3a7e5601d774.csv',
#  'SDL2_OpenGLES_rects_True_windup_python_c988fcc5-c42d-47d9-939a-e22c2878eb56.csv',
#  'SDL2_OPENGL_default_False_bitblt_e3d1e01b-7644-417d-b6fb-79c9521a25ff.csv',
#  'SDL2_OPENGL_default_False_getdbits_42d58786-d174-4ca6-bf90-59ee1eabdc23.csv',
#  'SDL2_OPENGL_default_False_getpixel_c32e2907-0ad6-4d4d-af40-f9465e28533b.csv',
#  'SDL2_OPENGL_default_False_windup_python_93c6be22-2ba1-4000-8b0c-2fb4a45fac61.csv',
#  'SDL2_OPENGL_default_True_bitblt_e9ce2320-b907-439c-9232-4944f8ff27ff.csv',
#  'SDL2_OPENGL_default_True_getdbits_67c6c319-7872-40ae-99d3-ff529400a62e.csv',
#  'SDL2_OPENGL_default_True_getpixel_d2f395f5-0804-4409-8346-398431d0c619.csv',
#  'SDL2_OPENGL_default_True_windup_python_c4c77203-ad90-46dc-8877-de0eb2bcfc77.csv',
#  'SDL2_OPENGL_rects_False_bitblt_84943e0a-56c0-4c0c-b44e-e743d157c811.csv',
#  'SDL2_OPENGL_rects_False_getdbits_6a8842b6-c5bf-4ba2-bdcb-9d2d7f82883d.csv',
#  'SDL2_OPENGL_rects_False_getpixel_cedab10b-5132-4b09-b05b-a2eaa5df6529.csv',
#  'SDL2_OPENGL_rects_False_windup_python_7bbd32b4-d7e8-47b4-93de-a5ee6873fb0c.csv',
#  'SDL2_OPENGL_rects_True_bitblt_16bc971c-f51e-4098-987c-48265a68bfe9.csv',
#  'SDL2_OPENGL_rects_True_getdbits_16e6c3d6-19c9-41f1-917f-b6a661a75a25.csv',
#  'SDL2_OPENGL_rects_True_getpixel_df781970-1a45-4648-9a64-c7eaba7e87ec.csv',
#  'SDL2_OPENGL_rects_True_windup_python_910e210d-3bc1-4be6-b576-e08f1a7e8446.csv',
#  'SDL2_Software_default_False_bitblt_094445cd-005b-4aa8-b225-b836028a8d1c.csv',
#  'SDL2_Software_default_False_getdbits_863babed-d9fb-4093-b066-016fe44e91dd.csv',
#  'SDL2_Software_default_False_getpixel_0adb6b82-6dfe-42e6-863e-702d9acc6c4d.csv',
#  'SDL2_Software_default_False_windup_python_4e10ce7e-be0f-49f9-aa01-cd5a0125876d.csv',
#  'SDL2_Software_default_True_bitblt_136bb7e2-af8e-4f22-9598-acfc8c433518.csv',
#  'SDL2_Software_default_True_getdbits_1eb4f66e-069c-45a0-b005-0df436f2b40c.csv',
#  'SDL2_Software_default_True_getpixel_ca13737b-e8e4-403a-8bb1-257b93afbdbd.csv',
#  'SDL2_Software_default_True_windup_python_074073e8-8646-4da2-a6ea-214f0774c8de.csv',
#  'SDL2_Software_rects_False_bitblt_56fbfbed-a40c-4c8d-a4e7-83ab3f59ed6d.csv',
#  'SDL2_Software_rects_False_getdbits_71339e08-4956-410e-9f73-561a1a2812c4.csv',
#  'SDL2_Software_rects_False_getpixel_5a1bf311-41f5-46d1-b6a9-ddfe914b5ea6.csv',
#  'SDL2_Software_rects_False_windup_python_fd078124-0f77-4603-9139-e1ef2f333567.csv',
#  'SDL2_Software_rects_True_bitblt_6d31d41a-b439-4886-92db-d95bc3c8b1fe.csv',
#  'SDL2_Software_rects_True_getdbits_4e8cd6de-7aec-41c9-86bb-e2213f51f3d8.csv',
#  'SDL2_Software_rects_True_getpixel_c10e3282-651a-4c4f-a54d-7424baa8e615.csv',
#  'SDL2_Software_rects_True_windup_python_3480965f-df50-4f0c-88a1-0f3c402ead8b.csv',
#  'tkinter_default_False_bitblt_cd90b2fc-9f07-4772-85d8-8a9480748fc4.csv',
#  'tkinter_default_False_getdbits_38edb631-2bcd-4d90-9576-de182c8ae7b1.csv',
#  'tkinter_default_False_getpixel_9fbdf05b-787d-452b-a419-07f070d089fd.csv',
#  'tkinter_default_False_windup_python_49b629bc-637c-4bd2-806e-32fd5931ca34.csv',
#  'tkinter_default_True_bitblt_3c7f0ea1-6a9c-4ddd-82ad-7b2b7792d2ff.csv',
#  'tkinter_default_True_getdbits_e6106b61-8fa4-46b6-a9f4-fa24c68645d0.csv',
#  'tkinter_default_True_getpixel_f93eea3c-4480-42d1-a12c-24f39ac16cf9.csv',
#  'tkinter_default_True_windup_python_8424bd9e-d8f0-42e6-a2bc-53fdfbf14c43.csv',
#  'tkinter_rects_False_bitblt_190dd219-cb37-45de-a12d-c4c379ff70a8.csv',
#  'tkinter_rects_False_getdbits_d5f0e7fd-527e-4753-a359-2f249d07c612.csv',
#  'tkinter_rects_False_getpixel_e1f05605-856c-4b16-9023-647784b9a549.csv',
#  'tkinter_rects_False_windup_python_ae4ccafc-1c4c-4825-8f8f-2a1fec5b865f.csv',
#  'tkinter_rects_True_bitblt_86862885-bedf-4c24-a09e-1a09c3eb8c83.csv',
#  'tkinter_rects_True_getdbits_d31d97e0-98d6-42f5-82d8-94aa6d313586.csv',
#  'tkinter_rects_True_getpixel_36188d01-57b1-4858-b152-4df0433b4e3b.csv',
#  'tkinter_rects_True_windup_python_368556ae-a99c-48d9-95e6-114ec550f4d0.csv',
#  'wxpython_default_False_bitblt_ddf96682-cece-4d08-b3f2-0f8446f29970.csv',
#  'wxpython_default_False_getdbits_6c37f8d8-705c-4cc1-936f-31a4c77099c8.csv',
#  'wxpython_default_False_getpixel_889e397a-ec03-4a86-b647-e7c1f5acc0ec.csv',
#  'wxpython_default_False_windup_python_855f53de-c93c-4ddd-b024-33b9f44da63d.csv',
#  'wxpython_default_True_bitblt_85456e4e-df62-4ad5-9224-4f0f8adce2de.csv',
#  'wxpython_default_True_getdbits_9423fa0e-8a3a-417b-88f1-268406bbd85c.csv',
#  'wxpython_default_True_getpixel_514acb08-c5c6-41e8-9573-90dfd047953a.csv',
#  'wxpython_default_True_windup_python_c587bb14-774e-49df-8c0b-fe11cc70df19.csv',
#  'wxpython_rects_False_bitblt_3ba46036-c43a-4e1d-8dcc-08488b60c739.csv',
#  'wxpython_rects_False_getdbits_492df004-2af8-4bdf-ac52-3e751d86e896.csv',
#  'wxpython_rects_False_getpixel_b0bebacf-0f86-4ffa-8b46-e2d6663554da.csv',
#  'wxpython_rects_False_windup_python_7c8195dd-a582-4243-a6c4-2bb4911cbd6f.csv',
#  'wxpython_rects_True_bitblt_5faab3cb-1e6c-48b4-9a88-61ec807b577d.csv',
#  'wxpython_rects_True_getdbits_f579063b-3513-46b8-88b0-5c924b8a1443.csv',
#  'wxpython_rects_True_getpixel_1a32c8af-3fed-4222-acd2-aa6ccb9bdd1a.csv',
#  'wxpython_rects_True_windup_python_bc58d963-a233-45e2-b6ad-68d0b015e522.csv']

# %%
dataframes = []
for file in files:
    dataframes.append(pd.read_csv(f"{PATH}/{file}"))
data_raw = pd.concat(dataframes)

# %%
# clean because windup not working with opengl based
# df.loc[~((df['col1'] == 'A') & (df['col2'] > 6))] 
data_clean = data_raw.loc[~((data_raw['program'] == 'windup_python') & (data_raw['framework'].str.contains('GL')))]

# %%
data = data_clean

# %% [markdown]
# ## End-to-end latencies with and without running framework tester
# ### Complexity: Default
#
# Almost the same -> no additional latency with framework tester

# %%
sns.set(rc={'figure.figsize':(15, 8)})
sns.boxplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running').set_title('end-to-end latencies with/without running fw-tester')
sns.stripplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(0, 90000)
for i in range(0, 20):
    plt.axhline(i*16.7*1000, color='red')
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_25752\4173412873.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running', dodge=True, color='black')

# %% [markdown]
# ### Complexity: Rects
#
# Also, no additional latency (even faster with running framework tester)

# %%
sns.boxplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running').set_title('end-to-end latencies with/without running fw-tester')
sns.stripplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(0, 200000)
for i in range(0, 20):
    plt.axhline(i*16.7*1000, color='red')
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_25752\3384622468.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running', dodge=True, color='black')

# %% [markdown]
# ## Framework latency by framework
# ### Complexity: Default
#
# no results for pyqt5 and wxpython because of border

# %%
sns.boxplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-1000, 25000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_25752\1753498729.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# (-1000.0, 25000.0)

# %% [markdown]
# ### Complexity: Rects

# %%
sns.boxplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-1000, 100000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_25752\84911319.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# (-1000.0, 100000.0)

# %% [markdown]
# ### Framework latency by complexity

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-5000, 150000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_25752\3399512195.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True, color='black')
# (-5000.0, 150000.0)

# %% [markdown]
# ### Framework latency by framework

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True, color=(0,0,0))
ax = plt.gca()
ax.set_ylim(-5000, 150000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_25752\3932135016.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#000000'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True, color=(0,0,0))
# (-5000.0, 150000.0)

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-5000, 150000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_25752\594577958.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='program', dodge=True, color='black')
# (-5000.0, 150000.0)

# %% [markdown]
# ## Difference (ete and fw) by program
# ### Complexity: Rects

# %%
sns.boxplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-80000, 100000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_25752\3421617578.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True, color='black')
# (-80000.0, 100000.0)

# %% [markdown]
# ### Complexity: Default

# %%
sns.set(rc={'figure.figsize':(13.7,8.27)})
sns.boxplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-80000, 80000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_25752\605666535.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True, color='black')
# (-80000.0, 80000.0)

# %%
sns.boxplot(data=data[(data['fw_running'] == True)], x='framework', y='diff', hue='complexity', dodge=True).set_title('')
sns.stripplot(data=data[(data['fw_running'] == True)], x='framework', y='diff', hue='complexity', dodge=True)
ax = plt.gca()
ax.set_ylim(-80000, 80000)
# Out:
# (-80000.0, 80000.0)
