# %% [markdown]
# # SDL Frameworks (480Hz, fullscreen, pixel [5,5], 50 iterations)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
PATH = "../../data/sdl_1112_480hz_55"

# %%
files = os.listdir(PATH)
files = [x for x in files if 'csv' in x]
files
# Out:
# ['SDL2_OpenGLES_default_False_bitblt_90e4b4b0-3d8b-4089-9774-10089e8c53c6.csv',
#  'SDL2_OpenGLES_default_False_getdbits_3ec55c1c-9fb9-46e1-8a1c-55bd0556ced0.csv',
#  'SDL2_OpenGLES_default_False_getpixel_019065fe-7577-4472-be12-92d54e1cb038.csv',
#  'SDL2_OpenGLES_default_False_windup_python_160ffe67-603d-44e2-b2b1-dc354dd98606.csv',
#  'SDL2_OpenGLES_default_False_windup_python_805fda4c-deee-4deb-9cf1-f6e93ccc85bc.csv',
#  'SDL2_OpenGLES_default_False_windup_python_d72e5788-de81-4c3e-8ec3-8e727b13b0a0.csv',
#  'SDL2_OpenGLES_default_False_windup_python_f039e0f7-3437-40f3-abcd-a8f4a3a99c76.csv',
#  'SDL2_OpenGLES_default_True_bitblt_be491fa2-fca4-471c-857f-d22dbe59c17c.csv',
#  'SDL2_OpenGLES_default_True_getdbits_b6021185-d87b-4b77-af15-4edd369da715.csv',
#  'SDL2_OpenGLES_default_True_getpixel_cb5f7f97-f51f-4316-9619-dcbb15b54236.csv',
#  'SDL2_OpenGLES_default_True_windup_python_9073521c-baf0-475c-acb7-6c1990f6439c.csv',
#  'SDL2_OpenGLES_rects_False_bitblt_ac9f302c-768e-4bb4-970a-608b519896e2.csv',
#  'SDL2_OpenGLES_rects_False_getdbits_42e50f87-f6e3-444e-b7c4-b830d7dd3122.csv',
#  'SDL2_OpenGLES_rects_False_getpixel_f953fe5e-ed94-4b58-b1fa-c0288ae6484e.csv',
#  'SDL2_OpenGLES_rects_False_windup_python_2c3cb7bc-b9c2-47dd-bbe0-ace6cada41d5.csv',
#  'SDL2_OpenGLES_rects_False_windup_python_6fedac07-1ab3-4231-9157-d20080fc3961.csv',
#  'SDL2_OpenGLES_rects_False_windup_python_9ab8c44f-20ae-461a-9e91-bbc6d0cbe6b1.csv',
#  'SDL2_OpenGLES_rects_False_windup_python_a144e959-898b-45bb-a032-6857453ed9d9.csv',
#  'SDL2_OpenGLES_rects_True_bitblt_2eefc5ca-b0e1-4398-933b-903f81cf1c78.csv',
#  'SDL2_OpenGLES_rects_True_getdbits_30b2da26-b718-4e82-a5f7-e30eeb51df04.csv',
#  'SDL2_OpenGLES_rects_True_getpixel_b685336e-b7ca-420f-a27d-10dd513a8d6e.csv',
#  'SDL2_OpenGLES_rects_True_windup_python_b5756bbc-e08d-448b-a801-f7fd7c1d958c.csv',
#  'SDL2_OPENGL_default_False_bitblt_3012e569-09a7-4431-b0e1-8e9d1a96dc90.csv',
#  'SDL2_OPENGL_default_False_getdbits_a61c6f55-6563-4a6b-996a-b76ef203778c.csv',
#  'SDL2_OPENGL_default_False_getpixel_c79e275a-2a3b-4396-809b-48b47f398f59.csv',
#  'SDL2_OPENGL_default_False_windup_python_03d0d75d-122e-4bc2-98df-000e8f6094f0.csv',
#  'SDL2_OPENGL_default_False_windup_python_3dec538d-b12b-462a-a35e-c73ef1cc8bb3.csv',
#  'SDL2_OPENGL_default_False_windup_python_df39c9f4-8e9b-41ad-9600-516fd6757771.csv',
#  'SDL2_OPENGL_default_False_windup_python_fee9f6d0-afb4-479b-864c-0698762a15dd.csv',
#  'SDL2_OPENGL_default_True_bitblt_bb867db0-594c-4002-8a89-59fa3cf6e726.csv',
#  'SDL2_OPENGL_default_True_getdbits_222bea1c-323c-47cd-a172-576415fd88ed.csv',
#  'SDL2_OPENGL_default_True_getpixel_e3806594-b04a-4051-a136-db79084a9daf.csv',
#  'SDL2_OPENGL_default_True_windup_python_2cb93e5c-c1e6-4366-8f27-0ae264ee2cdf.csv',
#  'SDL2_OPENGL_rects_False_bitblt_9437ae4f-5639-44fa-994e-19873dd93da8.csv',
#  'SDL2_OPENGL_rects_False_getdbits_244fbd07-0283-4797-8f4f-35380ff9f04b.csv',
#  'SDL2_OPENGL_rects_False_getpixel_28a5dfca-fbca-473a-95b1-2fdb961a241d.csv',
#  'SDL2_OPENGL_rects_False_windup_python_b58cd253-df5c-4303-ab7d-5f6e3bb6e2f3.csv',
#  'SDL2_OPENGL_rects_False_windup_python_c6f089c9-e228-4d53-aff2-c2749aa2496f.csv',
#  'SDL2_OPENGL_rects_False_windup_python_c6fa586d-d391-4238-be51-bf826a5ecaf5.csv',
#  'SDL2_OPENGL_rects_False_windup_python_ed497421-8101-4f65-b43a-d3b9067e7367.csv',
#  'SDL2_OPENGL_rects_True_bitblt_e484379d-9252-4cc5-a229-fb08e4a2ac9f.csv',
#  'SDL2_OPENGL_rects_True_getdbits_fc7feb31-f28f-4c54-8e31-3bb5b8d3b229.csv',
#  'SDL2_OPENGL_rects_True_getpixel_dc1eeee1-18ab-4c83-b161-6812a56e5660.csv',
#  'SDL2_OPENGL_rects_True_windup_python_c2b72480-8257-427a-985d-a2c3480f56a6.csv',
#  'SDL2_Software_default_False_bitblt_27c0dd75-0443-4d6b-b487-aee91874434a.csv',
#  'SDL2_Software_default_False_getdbits_c0e9642f-fcdd-45e4-9a1d-917d45a518cf.csv',
#  'SDL2_Software_default_False_getpixel_471a81bb-85e2-4914-87db-b6ca785bf6e6.csv',
#  'SDL2_Software_default_False_windup_python_4fd178be-3fa2-481e-8782-56e55aa59f51.csv',
#  'SDL2_Software_default_False_windup_python_55ddd1c3-9cd1-4e8b-b00d-86aae79635cb.csv',
#  'SDL2_Software_default_False_windup_python_88288c1e-4318-4de7-8a38-bd21f62eae33.csv',
#  'SDL2_Software_default_False_windup_python_c9942cd5-8486-471d-9ba4-7a9f83cbd452.csv',
#  'SDL2_Software_default_True_bitblt_723dce7c-b31a-49a7-ae1c-45dbf2976f64.csv',
#  'SDL2_Software_default_True_getdbits_e7c565cb-7de5-4804-be82-0a1d52e1de16.csv',
#  'SDL2_Software_default_True_getpixel_481fd73a-8272-4120-a3c5-d27a61675f38.csv',
#  'SDL2_Software_default_True_windup_python_1d26631a-59c7-4e01-b71b-fabee6e418cc.csv',
#  'SDL2_Software_default_True_windup_python_36b39fa5-7e2d-436d-9305-260e0c8dc22d.csv',
#  'SDL2_Software_default_True_windup_python_8c3ad0d6-b399-42cc-90cf-7687cc362741.csv',
#  'SDL2_Software_rects_False_bitblt_6aa1ce8f-9b27-4f0c-94b2-cc36a7e16896.csv',
#  'SDL2_Software_rects_False_getdbits_f323b334-e1d3-4630-a845-83ecc4252be0.csv',
#  'SDL2_Software_rects_False_getpixel_d5c84dd5-df69-449b-bc2d-4e833471024d.csv',
#  'SDL2_Software_rects_False_windup_python_04bf32c3-5190-40a2-b61c-5f9d62d46cca.csv',
#  'SDL2_Software_rects_False_windup_python_7053f3cb-c412-4333-9f87-dfca6532f29e.csv',
#  'SDL2_Software_rects_False_windup_python_a253272f-d1d4-47fb-9f19-04d5fc86ef3a.csv',
#  'SDL2_Software_rects_True_bitblt_6ff7388b-8ba0-4a93-969a-b0fa36449b2f.csv',
#  'SDL2_Software_rects_True_getdbits_f93cf1dd-827a-4a06-bd71-fadd74d9f87f.csv',
#  'SDL2_Software_rects_True_getpixel_a73b2d59-45c6-4029-9766-fd88c1ab06ec.csv',
#  'SDL2_Software_rects_True_windup_python_54acfb0a-2d83-449f-8cca-db739f3803fe.csv',
#  'SDL2_Software_rects_True_windup_python_b4fe55af-983f-44b3-83c4-ef062d0a8fdd.csv']

# %%
dataframes = []
for file in files:
    dataframes.append(pd.read_csv(f"{PATH}/{file}"))
data_raw = pd.concat(dataframes)

# %%
#clean because windup not working with opengl based
#df.loc[~((df['col1'] == 'A') & (df['col2'] > 6))] 
# data_clean = data_raw.loc[~((data_raw['fw_running'] == True) & (data_raw['fw'] == -1) & (data_raw['diff'] < 0))]
# data = data_clean

# %%
data = data_raw

# %% [markdown]
# ## End-to-end latencies with and without running framework tester
# ### Complexity: Default
#
# about 5ms difference
# with running fw testerm it's faster

# %%
sns.set(rc={'figure.figsize':(15, 8)})
sns.boxplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running').set_title('end-to-end latencies with/without running fw-tester: default')
sns.stripplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(0, 50000)
# for i in range(0, 20):
#     plt.axhline(i*2.1*1000, color='red')
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_27092\973406604.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
# (0.0, 50000.0)

# %% [markdown]
# ### Complexity: Rects
#
# Again, about 5ms difference
# Faster with running fw tester

# %%
sns.boxplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running').set_title('end-to-end latencies with/without running fw-tester')
sns.stripplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-10000, 80000)
# for i in range(0, 20):
#     plt.axhline(i*2.1*1000, color='red')
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_27092\3079506384.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
# (-10000.0, 80000.0)

# %% [markdown]
# ## Framework latency by framework
# ### Complexity: Default
#
# windup unrealistisch große werte(?)

# %%
sns.boxplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# ax = plt.gca()
# ax.set_ylim(-100000, 2000000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_27092\2579862291.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# <Axes: xlabel='framework', ylabel='fw'>

# %% [markdown]
# ### Complexity: Rects
# was soll das denn???

# %%
sns.boxplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-1000, 30000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_27092\1554111015.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# (-1000.0, 30000.0)

# %% [markdown]
# ### Framework latency by complexity

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-1000, 30000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_27092\585289270.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True, color='black')
# (-1000.0, 30000.0)

# %% [markdown]
# ### Framework latency by framework

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True, color=(0,0,0))
ax = plt.gca()
ax.set_ylim(-1000, 30000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_27092\513836321.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#000000'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True, color=(0,0,0))
# (-1000.0, 30000.0)

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='framework_complexity', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='framework_complexity', y='fw', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-1000, 30000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_27092\2891033835.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='framework_complexity', y='fw', hue='program', dodge=True, color='black')
# (-1000.0, 30000.0)

# %% [markdown]
# ## Difference (ete and fw) by program
# ### Complexity: Rects

# %%
sns.boxplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-1000, 70000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_27092\994543305.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True, color='black')
# (-1000.0, 70000.0)

# %% [markdown]
# ### Complexity: Default

# %%
sns.set(rc={'figure.figsize':(13.7,8.27)})
sns.boxplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-100000, 50000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_27092\3426558611.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True, color='black')
# (-100000.0, 50000.0)

# %%
sns.boxplot(data=data[(data['fw_running'] == True)], x='framework', y='diff', hue='complexity', dodge=True).set_title('')
sns.stripplot(data=data[(data['fw_running'] == True)], x='framework', y='diff', hue='complexity', dodge=True)
ax = plt.gca()
ax.set_ylim(-10000, 40000)
# for i in range(0, 20):
#     plt.axhline(i*2.1*1000, color='red')
# Out:
# (-10000.0, 40000.0)
