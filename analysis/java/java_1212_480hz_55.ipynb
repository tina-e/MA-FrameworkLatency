# %% [markdown]
# # SDL Frameworks (480Hz, fullscreen, pixel [5,5], 50 iterations)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
PATH = "../../data/java_c_1212_480hz_55"

# %%
files = os.listdir(PATH)
files = [x for x in files if 'csv' in x]
files
# Out:
# ['GLUT_default_False_bitblt_5f3fe940-6368-418a-b574-b31db6cdf38c.csv',
#  'GLUT_default_False_getdbits_02712dd6-f33f-4344-a12f-0cdff3400f05.csv',
#  'GLUT_default_False_getpixel_2ec06383-e576-4bac-b362-58e0f5e97b37.csv',
#  'GLUT_default_False_windup_python_b3defc04-073f-4e7d-82d3-4380a0c0e836.csv',
#  'GLUT_default_True_bitblt_fef96898-e0be-4167-8355-a92349f4559f.csv',
#  'GLUT_default_True_getdbits_f3f26e02-beef-418d-b921-5af28c5adc0c.csv',
#  'GLUT_default_True_getpixel_7fdbdfe4-2c22-4a4b-be0a-c64880debf5f.csv',
#  'GLUT_default_True_windup_python_d3369b04-8653-4a22-a566-c81e9b7a21f2.csv',
#  'GLUT_rects_False_bitblt_09473e14-698e-4b67-859f-511293c703ec.csv',
#  'GLUT_rects_False_getdbits_3f2525d3-44c1-4f74-a6a0-0609872d89c4.csv',
#  'GLUT_rects_False_getpixel_3cd4e3f4-8e66-4de4-9b1a-692e8a7e43e9.csv',
#  'GLUT_rects_False_windup_python_9c6b76e7-5a47-48fb-b9fa-e81a3f98a36c.csv',
#  'GLUT_rects_True_bitblt_b51a0e50-ba09-4e58-a45b-d697377ead2f.csv',
#  'GLUT_rects_True_getdbits_6d733737-885c-4124-acfc-d0039eff83fa.csv',
#  'GLUT_rects_True_getpixel_ecb8ac5d-d25d-4c17-88d9-483e10a068c8.csv',
#  'GLUT_rects_True_windup_python_4a916a7d-f918-459d-bbff-953b5eb63ee2.csv',
#  'Java2D_default_False_bitblt_8ce4eb66-863c-4dfd-af8e-961d2868f19e.csv',
#  'Java2D_default_False_getdbits_d6ba5013-5735-4513-b48d-3cf5c07c214e.csv',
#  'Java2D_default_False_getpixel_10b1d09a-4f37-47cc-9e78-47f6111ccda2.csv',
#  'Java2D_default_False_windup_python_c3795546-b0e2-46f2-abf4-7f52aa847aa9.csv',
#  'Java2D_default_True_bitblt_9a49305a-1131-48c9-be12-26d84431a7c0.csv',
#  'Java2D_default_True_getdbits_6beb176e-867d-4f55-8d95-7ba779fa0d64.csv',
#  'Java2D_default_True_getpixel_7fe23f70-260e-4b04-aa66-d25a1a188708.csv',
#  'Java2D_default_True_windup_python_33b13e34-fd5a-4256-b0c3-7dd5de89dc6e.csv',
#  'Java2D_rects_False_bitblt_31899f27-d131-4a47-a9df-60373e7b69bc.csv',
#  'Java2D_rects_False_getdbits_4372f3e5-3505-4053-9396-e1cfe791820b.csv',
#  'Java2D_rects_False_getpixel_f515f5e6-05b3-404e-8540-f5a7872f9034.csv',
#  'Java2D_rects_False_windup_python_f07bc2d4-4a96-44a8-a0ad-5b9d04008e9b.csv',
#  'Java2D_rects_True_bitblt_e230d0a0-d2cf-4646-b550-b45a86e1facb.csv',
#  'Java2D_rects_True_getdbits_fafb0352-3d32-44cb-875c-64afc3b8bd48.csv',
#  'Java2D_rects_True_getpixel_8df26653-8516-46ab-9a8a-12c02e6b4558.csv',
#  'Java2D_rects_True_windup_python_ee0ec695-7917-4443-bccb-93d58828b65c.csv',
#  'JavaSwing_default_False_bitblt_40b5163d-37dd-422f-b3d2-83c66ec099a4.csv',
#  'JavaSwing_default_False_getdbits_8e2e344b-7efc-46d3-95da-5b0d8df87595.csv',
#  'JavaSwing_default_False_getpixel_a99113c0-1f64-49b7-af59-0ba10723af42.csv',
#  'JavaSwing_default_False_windup_python_a6de632f-4366-47d3-a85b-32aade570ded.csv',
#  'JavaSwing_default_True_bitblt_4ce69fdc-d020-45e1-bbfa-b185db8a3cf1.csv',
#  'JavaSwing_default_True_getdbits_b6acf365-a166-4367-b8bb-c042c8657228.csv',
#  'JavaSwing_default_True_getpixel_a11bd959-4f3c-4555-89a6-e47b093cba9e.csv',
#  'JavaSwing_default_True_windup_python_176f2d9d-6a15-46ba-9a62-a0547aeaa4a2.csv',
#  'JavaSwing_rects_False_bitblt_81d4fd46-1986-439f-8caf-00c234a2c404.csv',
#  'JavaSwing_rects_False_getdbits_606eb2a1-678a-42d2-bb59-5cac1a2c1ea7.csv',
#  'JavaSwing_rects_False_getpixel_c5e12841-b2f2-4403-8b22-f4e3c7421450.csv',
#  'JavaSwing_rects_False_windup_python_40b0bb7f-8e03-4d4d-9102-8a50cbc12ba1.csv',
#  'JavaSwing_rects_True_bitblt_ac18a049-13c1-4e78-ab39-e799e1c5ac4d.csv',
#  'JavaSwing_rects_True_getdbits_f5472809-5555-45f9-8256-ce00e0b89e3f.csv',
#  'JavaSwing_rects_True_getpixel_7b0a9153-bd65-4c8b-b830-592f6402274b.csv',
#  'JavaSwing_rects_True_windup_python_5f30108a-7e94-4d61-acbd-10c9d47954c0.csv']

# %%
dataframes = []
for file in files:
    dataframes.append(pd.read_csv(f"{PATH}/{file}"))
data_raw = pd.concat(dataframes)

# %%
#clean because windup not working with opengl based
#df.loc[~((df['col1'] == 'A') & (df['col2'] > 6))] 
# data_clean = data_raw.loc[~((data_raw['fw_running'] == True) & (data_raw['fw'] == -1) & (data_raw['diff'] < 0))]
# data = data_clean

# %%
data = data_raw

# %% [markdown]
# ## End-to-end latencies with and without running framework tester
# ### Complexity: Default
#
# about 5ms difference
# with running fw testerm it's faster

# %%
sns.set(rc={'figure.figsize':(15, 8)})
sns.boxplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running').set_title('end-to-end latencies with/without running fw-tester: default')
sns.stripplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
# ax = plt.gca()
# ax.set_ylim(0, 50000)
# for i in range(0, 20):
#     plt.axhline(i*2.1*1000, color='red')
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_26320\2995994967.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
# <Axes: title={'center': 'end-to-end latencies with/without running fw-tester: default'}, xlabel='program', ylabel='ete'>

# %% [markdown]
# ### Complexity: Rects
#
# Again, about 5ms difference
# Faster with running fw tester

# %%
sns.boxplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running').set_title('end-to-end latencies with/without running fw-tester')
sns.stripplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(0, 40000)
# for i in range(0, 20):
#     plt.axhline(i*2.1*1000, color='red')
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_26320\3745585834.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
# (0.0, 40000.0)

# %% [markdown]
# ## Framework latency by framework
# ### Complexity: Default
#
# windup unrealistisch große werte(?)

# %%
sns.boxplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# ax = plt.gca()
# ax.set_ylim(-100000, 2000000)
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_26320\2579862291.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# <Axes: xlabel='framework', ylabel='fw'>

# %% [markdown]
# ### Complexity: Rects
# was soll das denn???

# %%
sns.boxplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# ax = plt.gca()
# ax.set_ylim(-1000, 30000)
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_26320\2532508427.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# <Axes: xlabel='framework', ylabel='fw'>

# %% [markdown]
# ### Framework latency by complexity

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True, color='black')
# ax = plt.gca()
# ax.set_ylim(-1000, 30000)
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_26320\2864254672.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True, color='black')
# <Axes: xlabel='complexity', ylabel='fw'>

# %% [markdown]
# ### Framework latency by framework

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True, color=(0,0,0))
ax = plt.gca()
ax.set_ylim(-1000, 30000)
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_26320\513836321.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#000000'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True, color=(0,0,0))
# (-1000.0, 30000.0)

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='framework_complexity', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='framework_complexity', y='fw', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-1000, 15000)
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_26320\3643607887.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='framework_complexity', y='fw', hue='program', dodge=True, color='black')
# (-1000.0, 15000.0)

# %% [markdown]
# ## Difference (ete and fw) by program
# ### Complexity: Rects

# %%
sns.boxplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-1000, 20000)
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_26320\457875842.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True, color='black')
# (-1000.0, 20000.0)

# %% [markdown]
# ### Complexity: Default

# %%
sns.set(rc={'figure.figsize':(13.7,8.27)})
sns.boxplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-100000, 50000)
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_26320\3426558611.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True, color='black')
# (-100000.0, 50000.0)

# %%
sns.boxplot(data=data[(data['fw_running'] == True)], x='framework', y='diff', hue='complexity', dodge=True).set_title('')
sns.stripplot(data=data[(data['fw_running'] == True)], x='framework', y='diff', hue='complexity', dodge=True)
ax = plt.gca()
ax.set_ylim(-10000, 40000)
# for i in range(0, 20):
#     plt.axhline(i*2.1*1000, color='red')
# Out:
# (-10000.0, 40000.0)
