# %% [markdown]
# # Python Frameworks (480Hz, nicht-fullscreen(most), pixel [5,5], 50 iterations)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
PATH = "../../data/python_0512_480hz_55"

# %%
files = os.listdir(PATH)
files = [x for x in files if 'csv' in x]
files
# Out:
# ['pygame_default_False_bitblt_ac54fb83-cfa3-4f5c-857e-5ebcc7b00a5b.csv',
#  'pygame_default_False_getdbits_48a9dd85-9ef9-4cd9-834f-92f0c8e351ab.csv',
#  'pygame_default_False_getpixel_56214f51-b076-4683-8b4a-ed033c763edb.csv',
#  'pygame_default_False_windup_python_f65f0a0f-3a39-4095-927b-0936a3ee0705.csv',
#  'pygame_default_True_bitblt_1f6466b6-41ce-4499-b944-fb122796e2e1.csv',
#  'pygame_default_True_getdbits_5fda8acc-38a2-4c98-a21d-dd11d4dc9f85.csv',
#  'pygame_default_True_getpixel_f6520638-a0a4-40b0-97a4-fdf011a76c9f.csv',
#  'pygame_default_True_windup_python_e69e2e0b-ced9-4c6e-8c99-b465a61b47bf.csv',
#  'pygame_rects_False_bitblt_6aeb352f-2758-4456-9eda-28479e952399.csv',
#  'pygame_rects_False_getdbits_04f02c97-0347-4e9f-b145-94351e16e477.csv',
#  'pygame_rects_False_getpixel_ca892506-1839-48a0-aec4-27c3c17eb1bc.csv',
#  'pygame_rects_False_windup_python_2ba172e9-d52c-435a-8c57-3bb525559691.csv',
#  'pygame_rects_True_bitblt_b8e2f7e7-e42c-43d8-9d9a-35f5594f48d7.csv',
#  'pygame_rects_True_getdbits_35edaa04-d147-4f21-ba41-9035929b4fab.csv',
#  'pygame_rects_True_getpixel_e0b9581f-98fd-4290-b846-fca736e724bb.csv',
#  'pygame_rects_True_windup_python_b5ff55bd-6407-4b46-974f-e14d001ed51f.csv',
#  'pyqt5_default_False_bitblt_84d88823-99e8-47ad-8369-c9ec3727afb0.csv',
#  'pyqt5_default_False_getdbits_27923b47-d897-489e-8bd3-86ce8f3e5ce6.csv',
#  'pyqt5_default_False_getpixel_cca2d7d2-dc0b-41d3-bb6d-9732afb08ada.csv',
#  'pyqt5_default_False_windup_python_9cfdc7dc-e9d7-4eab-9723-b433be326433.csv',
#  'pyqt5_default_True_bitblt_5ab07954-46d6-4485-973d-5597b53bfdbf.csv',
#  'pyqt5_default_True_getdbits_12de9be2-0462-41c5-9c59-5d5c19267522.csv',
#  'pyqt5_default_True_getpixel_76d097cd-b95d-4768-b6a5-04e75143ec9f.csv',
#  'pyqt5_default_True_windup_python_a65ca8ce-83db-445c-b22e-e34cc8de225a.csv',
#  'pyqt5_rects_False_bitblt_6457c728-8497-4dc3-a343-ca7a38fc3e2d.csv',
#  'pyqt5_rects_False_getdbits_76ed244e-f539-4ef8-b2b9-ecd6093e1d38.csv',
#  'pyqt5_rects_False_getpixel_7c70b1de-0ede-4c93-a1f1-eff29544ccea.csv',
#  'pyqt5_rects_False_windup_python_edc974a3-f8fc-4e65-b388-3c783c9d51b3.csv',
#  'pyqt5_rects_True_bitblt_308f1c68-067d-44ad-b03f-36c3e90f4010.csv',
#  'pyqt5_rects_True_getdbits_535ea860-78e1-4b1e-b8eb-debdd6866cfe.csv',
#  'pyqt5_rects_True_getpixel_4c630e8c-9928-4847-8919-b91b4a283d24.csv',
#  'pyqt5_rects_True_windup_python_e9c1a2eb-662e-448c-ad34-350a1a232a6a.csv',
#  'pyqt6_default_False_bitblt_5f2b773a-a718-47e8-bcce-afc4f6bdfe5f.csv',
#  'pyqt6_default_False_getdbits_44dc4eb0-6d4f-418f-b088-d6c96d2ec54d.csv',
#  'pyqt6_default_False_getpixel_04c84a21-4e31-4f5d-8de9-01108be66b9f.csv',
#  'pyqt6_default_False_windup_python_09492801-df5c-40ab-bbe2-4b34abeb54ca.csv',
#  'pyqt6_default_True_bitblt_3fc3caa9-8563-4efc-9ca0-1d3ed8047b9d.csv',
#  'pyqt6_default_True_getdbits_b3930f46-96c2-4f73-b065-17fb042941d0.csv',
#  'pyqt6_default_True_getpixel_eb703f5c-bbe2-47cc-8450-4301ffc12c40.csv',
#  'pyqt6_default_True_windup_python_73f2232e-4c9a-4859-8f2c-414ec223517d.csv',
#  'pyqt6_rects_False_bitblt_4f84c1e3-a9b3-4c9d-9fb9-741089b12698.csv',
#  'pyqt6_rects_False_getdbits_eb972d28-f0fe-4abb-ad6a-bb66aacecebe.csv',
#  'pyqt6_rects_False_getpixel_f44d49cd-e117-4fd5-81c8-55484586f2a2.csv',
#  'pyqt6_rects_False_windup_python_e0a257b0-a2a9-4421-93f0-57b794884c07.csv',
#  'pyqt6_rects_True_bitblt_e1e99a94-6670-4bf3-b60e-cdbd4cc51517.csv',
#  'pyqt6_rects_True_getdbits_3c1b44eb-0dfd-4a0d-bf91-7fd69b2b6c1e.csv',
#  'pyqt6_rects_True_getpixel_29a822f0-e272-4259-bd12-626b9e78b969.csv',
#  'pyqt6_rects_True_windup_python_0f7634ac-532b-467b-85c7-4a0ab95617f6.csv',
#  'tkinter_default_False_bitblt_8492fe45-e929-45b1-ba17-d889ee4f7689.csv',
#  'tkinter_default_False_getdbits_62c1b158-a1cd-4292-af2d-7e6ddfbce0ae.csv',
#  'tkinter_default_False_getpixel_725c6605-6044-43da-8c54-7866f9ec1d65.csv',
#  'tkinter_default_False_windup_python_17881981-8691-4b4e-b20c-f8c101c4d06b.csv',
#  'tkinter_default_True_bitblt_d577ac42-0732-4684-8308-a883886c6127.csv',
#  'tkinter_default_True_getdbits_6ee4248c-89f7-4fed-8891-f8840c8c14b8.csv',
#  'tkinter_default_True_getpixel_09605af2-cb2d-479d-baeb-1df5acdb7254.csv',
#  'tkinter_default_True_windup_python_62b13cb4-f7e6-42a0-aa0a-9c6e23e03157.csv',
#  'tkinter_rects_False_bitblt_3efa5c94-a3c0-4c89-b5e3-18de0aadacde.csv',
#  'tkinter_rects_False_getdbits_c8d4a1cf-8328-474d-ab44-560b6a565166.csv',
#  'tkinter_rects_False_getpixel_0819de9f-d814-4353-8424-7667e32006a4.csv',
#  'tkinter_rects_False_windup_python_928e31d7-aef4-4832-990f-b42e949f0753.csv',
#  'tkinter_rects_True_bitblt_99cfe66e-9319-485f-a1e5-06ccd996b19b.csv',
#  'tkinter_rects_True_getdbits_6ae70d2a-3733-4654-982f-460fee31414e.csv',
#  'tkinter_rects_True_getpixel_78f89e71-6e93-4bfe-8e7d-75dc9b1db58d.csv',
#  'tkinter_rects_True_windup_python_0306658d-5552-4f50-932c-90efa7656d91.csv',
#  'wxpython_default_False_bitblt_414ba648-b927-4c6b-b0c7-d7e83731a88b.csv',
#  'wxpython_default_False_getdbits_83bc0b2b-bf7a-4a6c-a291-3ffe57d7c16e.csv',
#  'wxpython_default_False_getpixel_23afe032-5571-4fe9-86a1-9b97b53abad0.csv',
#  'wxpython_default_False_windup_python_e0f81af6-b980-4fb4-b8dc-8dbc7c024548.csv',
#  'wxpython_default_True_bitblt_07b9be52-524e-4ca4-9716-005c77838384.csv',
#  'wxpython_default_True_getdbits_d59b6747-98c2-49a6-8a25-0928a1ece322.csv',
#  'wxpython_default_True_getpixel_b9569792-027f-4cd8-9e1a-a72f723e8530.csv',
#  'wxpython_default_True_windup_python_880d1c7e-e38f-4e81-b6a1-1d8edad2ef0b.csv',
#  'wxpython_rects_False_bitblt_889c547d-4b53-4509-92b1-9f2ae743a5c6.csv',
#  'wxpython_rects_False_getdbits_2a8b731c-dcfb-4964-97c5-103890e86a05.csv',
#  'wxpython_rects_False_getpixel_9ec1d76d-ca76-4925-99f0-3dc4764a1795.csv',
#  'wxpython_rects_False_windup_python_5ab8713c-2042-4b98-947e-ed41d3226568.csv',
#  'wxpython_rects_True_bitblt_3c523d0f-9204-4ed3-8843-aea4507a309f.csv',
#  'wxpython_rects_True_getdbits_bf0f2a76-4a26-44b2-b07d-00e83b507f83.csv',
#  'wxpython_rects_True_getpixel_e7ae3aa6-07fc-4074-96fd-5d05210058d2.csv',
#  'wxpython_rects_True_windup_python_69884978-a3b3-4ac8-8e42-b5791f1809cb.csv']

# %%
dataframes = []
for file in files:
    dataframes.append(pd.read_csv(f"{PATH}/{file}"))
data_raw = pd.concat(dataframes)

# %%
# clean because windup not working with opengl based
# df.loc[~((df['col1'] == 'A') & (df['col2'] > 6))] 
# data_clean = data_raw.loc[~((data_raw['fw_running'] == True) & (data_raw['fw'] == -1) & (data_raw['diff'] < 0))]
# data = data_clean

# %%
data = data_raw

# %% [markdown]
# ## End-to-end latencies with and without running framework tester
# ### Complexity: Default
#
# about 5ms difference
# with running fw testerm it's faster

# %%
sns.set(rc={'figure.figsize':(15, 8)})
sns.boxplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running').set_title('end-to-end latencies with/without running fw-tester: default')
sns.stripplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(0, 35000)
# for i in range(0, 20):
#     plt.axhline(i*2.1*1000, color='red')
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_29028\3130854144.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
# (0.0, 35000.0)

# %% [markdown]
# ### Complexity: Rects
#
# Again, about 5ms difference
# Faster with running fw tester

# %%
sns.boxplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running').set_title('end-to-end latencies with/without running fw-tester')
sns.stripplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(0, 150000)
# for i in range(0, 20):
#     plt.axhline(i*2.1*1000, color='red')
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_29028\2151654977.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
# (0.0, 150000.0)

# %% [markdown]
# ## Framework latency by framework
# ### Complexity: Default
#
# windup unrealistisch große werte(?)

# %%
sns.boxplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# ax = plt.gca()
# ax.set_ylim(-1000, 15000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_29028\785719403.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# <Axes: xlabel='framework', ylabel='fw'>

# %% [markdown]
# ### Complexity: Rects
# was soll das denn???

# %%
sns.boxplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# ax = plt.gca()
# ax.set_ylim(-1000, 50000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_29028\2191301594.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# <Axes: xlabel='framework', ylabel='fw'>

# %% [markdown]
# ### Framework latency by complexity

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True, color='black')
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_29028\252265620.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True, color='black')
# <Axes: xlabel='complexity', ylabel='fw'>

# %% [markdown]
# ### Framework latency by framework

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True, color=(0,0,0))
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_29028\2248004208.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#000000'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True, color=(0,0,0))
# <Axes: xlabel='framework', ylabel='fw'>

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='framework_complexity', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='framework_complexity', y='fw', hue='program', dodge=True, color='black')
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_29028\3460521000.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='framework_complexity', y='fw', hue='program', dodge=True, color='black')
# <Axes: xlabel='framework_complexity', ylabel='fw'>

# %% [markdown]
# ## Difference (ete and fw) by program
# ### Complexity: Rects

# %%
sns.boxplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True, color='black')
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_29028\902970262.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True, color='black')
# <Axes: xlabel='framework', ylabel='diff'>

# %% [markdown]
# ### Complexity: Default

# %%
sns.set(rc={'figure.figsize':(13.7,8.27)})
sns.boxplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-20000, 30000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_29028\4192689939.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True, color='black')
# (-20000.0, 30000.0)

# %%
sns.boxplot(data=data[(data['fw_running'] == True)], x='framework', y='diff', hue='complexity', dodge=True).set_title('')
sns.stripplot(data=data[(data['fw_running'] == True)], x='framework', y='diff', hue='complexity', dodge=True)
# ax = plt.gca()
# ax.set_ylim(-10000, 40000)
# for i in range(0, 20):
#     plt.axhline(i*2.1*1000, color='red')
# Out:
# <Axes: xlabel='framework', ylabel='diff'>
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
