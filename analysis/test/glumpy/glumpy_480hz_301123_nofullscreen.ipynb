# %% [markdown]
# # Glumpy (480Hz, nicht-fullscreen, pixel [5,5], 50 iterations)
# Frameworks
# - qt
# - pyglet
# - glfw
# - sdl/pygame

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
PATH = "../../data/glumpy/glumpy_301123_55_480hz"

# %%
files = os.listdir(PATH)
files = [x for x in files if 'csv' in x]
files
# Out:
# ['glumpy_glfw_default_False_bitblt_701418ac-49fe-4137-a6b0-041750c54e26.csv',
#  'glumpy_glfw_default_False_getdbits_72e2fed3-76d7-4332-b199-8d718fc4434b.csv',
#  'glumpy_glfw_default_False_getpixel_640fab74-ab3e-4c9f-932f-39c1048db4f7.csv',
#  'glumpy_glfw_default_False_windup_python_80f01740-9343-4756-96f3-76d453c5df5d.csv',
#  'glumpy_glfw_default_True_bitblt_99d3c043-aa8b-4284-a7ae-66a2824dd6ba.csv',
#  'glumpy_glfw_default_True_getdbits_50bd0e2c-5b18-4de8-b2f3-29e4d2280ec4.csv',
#  'glumpy_glfw_default_True_getpixel_ac849e7e-4ff8-4c44-9fc7-f21a88992d48.csv',
#  'glumpy_glfw_default_True_windup_python_056655f8-d871-447d-8f10-8c19d7a0f5d9.csv',
#  'glumpy_glfw_rects_False_bitblt_41f353c5-7cd5-41de-9aa4-913cfdf9dbc6.csv',
#  'glumpy_glfw_rects_False_getdbits_83527afb-174f-4ec7-94fe-7fc412f0dd4e.csv',
#  'glumpy_glfw_rects_False_getpixel_7a51c160-219c-4a50-9115-3d043b3c16d4.csv',
#  'glumpy_glfw_rects_False_windup_python_cdd75835-2920-4b59-8a6e-dfe2dd8aa4eb.csv',
#  'glumpy_glfw_rects_True_bitblt_f22ad0e4-6461-45de-a0d3-4e2d3e530f12.csv',
#  'glumpy_glfw_rects_True_getdbits_ea4f74d9-2793-41e2-8e23-c256cb5f06e0.csv',
#  'glumpy_glfw_rects_True_getpixel_7e6147ff-c092-42c8-b7c3-22e70c58108f.csv',
#  'glumpy_glfw_rects_True_windup_python_6d938546-3dd4-4520-b062-1335d361ba6d.csv',
#  'glumpy_pyglet_default_False_bitblt_88748e87-876e-4343-8073-ba1584ae8e07.csv',
#  'glumpy_pyglet_default_False_getdbits_bf7333f2-efc4-4e4d-ba0a-e7404ca39886.csv',
#  'glumpy_pyglet_default_False_getpixel_a12d3a7c-56c7-44b1-87b6-1bf1dc2ed3c5.csv',
#  'glumpy_pyglet_default_False_windup_python_08db0d47-ec82-442c-8acc-18079ea1a636.csv',
#  'glumpy_pyglet_default_True_bitblt_4eb70bd6-8ea3-4db2-a990-2af0042301cd.csv',
#  'glumpy_pyglet_default_True_getdbits_2ce041cb-ba2d-48cf-ada4-895cc56837a4.csv',
#  'glumpy_pyglet_default_True_getpixel_0dd2ca4a-ee08-4046-a51e-29743ade712e.csv',
#  'glumpy_pyglet_default_True_windup_python_c08cf449-442e-448e-94c3-13a3dcc27e8d.csv',
#  'glumpy_pyglet_rects_False_bitblt_9953ce75-e543-4fa2-a099-17a366291be2.csv',
#  'glumpy_pyglet_rects_False_getdbits_8e4b65e9-aeda-4055-be72-54b89832e90b.csv',
#  'glumpy_pyglet_rects_False_getpixel_c06632fd-b133-4bf7-b4b0-280a7af85098.csv',
#  'glumpy_pyglet_rects_False_windup_python_96d45f00-0040-4f81-95b4-8aec98c7b81d.csv',
#  'glumpy_pyglet_rects_True_bitblt_ca8ea90f-dc0c-444f-9ee6-87774c35401a.csv',
#  'glumpy_pyglet_rects_True_getdbits_76314b24-f943-4a99-bb99-016506ffcc96.csv',
#  'glumpy_pyglet_rects_True_getpixel_93d1f1de-6c56-481e-8319-cfd1ca4f9650.csv',
#  'glumpy_pyglet_rects_True_windup_python_70be9ca3-9789-413f-a036-4b662c9fcbc4.csv',
#  'glumpy_qt5_default_False_bitblt_a3c75e80-03d2-45a3-9c03-9c21c002e705.csv',
#  'glumpy_qt5_default_False_getdbits_9ea87118-737e-4cd3-ae76-8cef1588623d.csv',
#  'glumpy_qt5_default_False_getpixel_74b2f747-40d1-48ff-a0e3-4c779f1f53d1.csv',
#  'glumpy_qt5_default_False_windup_python_16df9301-6968-4790-af14-bcc259e95292.csv',
#  'glumpy_qt5_default_True_bitblt_6b42cb30-1415-4b7f-a13d-a9d49b3d7530.csv',
#  'glumpy_qt5_default_True_getdbits_912010fd-559c-42a0-bf78-7a9ce6053d22.csv',
#  'glumpy_qt5_default_True_getpixel_90713750-d01f-4415-b618-051532aaf2d5.csv',
#  'glumpy_qt5_default_True_windup_python_9de85c32-0f35-449a-ab24-e06106bf2c00.csv',
#  'glumpy_qt5_rects_False_bitblt_91020427-988c-43d4-a564-f476037633e5.csv',
#  'glumpy_qt5_rects_False_getdbits_ec73c246-779d-4caf-9b7f-1d179623401d.csv',
#  'glumpy_qt5_rects_False_getpixel_b8c29a20-d2bd-4eb6-85cd-41313466c06e.csv',
#  'glumpy_qt5_rects_False_windup_python_c220a474-f6e2-4354-995e-fe821f0b7a6a.csv',
#  'glumpy_qt5_rects_True_bitblt_3a0cde07-ae77-43a9-a1e2-9b4311c6c6a8.csv',
#  'glumpy_qt5_rects_True_getdbits_0b40b42a-4a0c-4843-b953-743ba489093e.csv',
#  'glumpy_qt5_rects_True_getpixel_24ecfb25-bdf4-4852-9e6d-6c90a85d918d.csv',
#  'glumpy_qt5_rects_True_windup_python_30a7ed55-a992-4c27-b989-f9057e31829f.csv',
#  'glumpy_sdl_default_False_bitblt_a8e814b9-c1c5-4135-a5b0-76c7064be661.csv',
#  'glumpy_sdl_default_False_getdbits_6e336907-60df-4d19-99a7-1301604f7f29.csv',
#  'glumpy_sdl_default_False_getpixel_36abeeb3-e528-411c-b077-a935ad655703.csv',
#  'glumpy_sdl_default_False_windup_python_a4b83457-7fcc-4870-a35e-e16227952f25.csv',
#  'glumpy_sdl_default_True_bitblt_04a5c3bc-f4f7-4fd6-a09f-527dd02b2e36.csv',
#  'glumpy_sdl_default_True_getdbits_8b707efc-80b2-4a17-ba21-86d511f59629.csv',
#  'glumpy_sdl_default_True_getpixel_595f5f45-caee-460a-9f50-ddec99d2824c.csv',
#  'glumpy_sdl_default_True_windup_python_ad3195a9-ed79-4a76-a624-58ff5884111d.csv',
#  'glumpy_sdl_rects_False_bitblt_7ed944ad-1907-41fb-941d-cae680d80b4e.csv',
#  'glumpy_sdl_rects_False_getdbits_4b6d1091-293d-4c61-93a4-366f2d19535f.csv',
#  'glumpy_sdl_rects_False_getpixel_bba911d7-0e1f-4354-b448-b73b69e986ca.csv',
#  'glumpy_sdl_rects_False_windup_python_eb0964ee-02b1-4c8a-9115-b72a6b0c05a9.csv',
#  'glumpy_sdl_rects_True_bitblt_287e26e1-e957-4023-8dac-123c00aac484.csv',
#  'glumpy_sdl_rects_True_getdbits_89ab68a1-9bf7-4b92-b410-37be0c562259.csv',
#  'glumpy_sdl_rects_True_getpixel_64aaad90-7d10-4f78-ad74-dbcc704f8693.csv',
#  'glumpy_sdl_rects_True_windup_python_666ca9ca-19ba-47f0-9d5f-9f7eb5a246c4.csv']

# %%
dataframes = []
for file in files:
    dataframes.append(pd.read_csv(f"{PATH}/{file}"))
data_raw = pd.concat(dataframes)

# %%
# clean because windup not working with opengl based
# df.loc[~((df['col1'] == 'A') & (df['col2'] > 6))] 
data_clean = data_raw.loc[~((data_raw['fw_running'] == True) & (data_raw['fw'] == -1) & (data_raw['diff'] < 0))]
data = data_clean

# %% [markdown]
# ## End-to-end latencies with and without running framework tester
# ### Complexity: Default
#
# Almost the same -> no additional latency with framework tester

# %%
sns.set(rc={'figure.figsize':(15, 8)})
sns.boxplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running').set_title('end-to-end latencies with/without running fw-tester')
sns.stripplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(0, 20000)
for i in range(0, 20):
    plt.axhline(i*2.1*1000, color='red')
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_36968\3893092759.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running', dodge=True, color='black')

# %% [markdown]
# ### Complexity: Rects
#
# Also, no additional latency (even faster with running framework tester)

# %%
sns.boxplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running').set_title('end-to-end latencies with/without running fw-tester')
sns.stripplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(0, 50000)
for i in range(0, 20):
    plt.axhline(i*2.1*1000, color='red')
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_36968\964307136.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running', dodge=True, color='black')

# %% [markdown]
# ## Framework latency by framework
# ### Complexity: Default
#
# no results for pyqt5 and wxpython because of border

# %%
sns.boxplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-1000, 25000)
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_36968\1753498729.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# (-1000.0, 25000.0)

# %% [markdown]
# ### Complexity: Rects

# %%
sns.boxplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(-1000, 40000)
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_36968\1174379519.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# (-1000.0, 40000.0)

# %% [markdown]
# ### Framework latency by complexity

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True, color='black')
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_36968\252265620.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True, color='black')
# <Axes: xlabel='complexity', ylabel='fw'>

# %% [markdown]
# ### Framework latency by framework

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True, color=(0,0,0))
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_36968\2248004208.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#000000'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True, color=(0,0,0))
# <Axes: xlabel='framework', ylabel='fw'>

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='framework_complexity', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='framework_complexity', y='fw', hue='program', dodge=True, color='black')
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_36968\3460521000.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='framework_complexity', y='fw', hue='program', dodge=True, color='black')
# <Axes: xlabel='framework_complexity', ylabel='fw'>

# %% [markdown]
# ## Difference (ete and fw) by program
# ### Complexity: Rects

# %%
sns.boxplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True, color='black')
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_36968\902970262.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True, color='black')
# <Axes: xlabel='framework', ylabel='diff'>

# %% [markdown]
# ### Complexity: Default

# %%
sns.set(rc={'figure.figsize':(13.7,8.27)})
sns.boxplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True, color='black')
ax = plt.gca()
ax.set_ylim(8000, 12000)
# Out:
# C:\Users\Martina Emmert\AppData\Local\Temp\ipykernel_36968\1094168428.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True, color='black')
# (8000.0, 12000.0)

# %%
sns.boxplot(data=data[(data['fw_running'] == True)], x='framework', y='diff', hue='complexity', dodge=True).set_title('')
sns.stripplot(data=data[(data['fw_running'] == True)], x='framework', y='diff', hue='complexity', dodge=True)
ax = plt.gca()
ax.set_ylim(-10000, 40000)
for i in range(0, 20):
    plt.axhline(i*2.1*1000, color='red')
