# %% [markdown]
# # SDL Frameworks (480Hz, fullscreen, pixel [5,5], 50 iterations)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
PATH = "../../data/other_1312_480hz_55"

# %%
files = os.listdir(PATH)
files = [x for x in files if 'csv' in x]
files
# Out:
# ['GLUT_default_False_ctypes_reader_522753aa-f9b1-4e44-9268-644c8a040b9a.csv',
#  'GLUT_default_False_pyautogui_reader_db16f276-afa0-4d05-b469-67d205cd5222.csv',
#  'GLUT_default_True_ctypes_reader_c37a377d-3136-4df1-a11f-0bf86ecf22c8.csv',
#  'GLUT_default_True_pyautogui_reader_c79bed2b-439b-4d2d-a8ec-2bf00d6b9b0a.csv',
#  'GLUT_rects_False_ctypes_reader_638579bb-d6b1-4069-8689-ac304984ffd8.csv',
#  'GLUT_rects_False_pyautogui_reader_0b2d703a-61fe-46bf-991c-429aa4329449.csv',
#  'GLUT_rects_True_ctypes_reader_e34dd31d-bbd1-44c9-a893-3e1ee5e5f397.csv',
#  'GLUT_rects_True_pyautogui_reader_66604a98-620b-486d-b524-b06e1003d581.csv',
#  'Java2D_default_False_ctypes_reader_c57e20bc-1746-4504-9003-944509eafc09.csv',
#  'Java2D_default_False_pyautogui_reader_00186ce2-014c-4650-84c6-f47cfab0ee66.csv',
#  'Java2D_default_True_ctypes_reader_9a9284f8-2d0c-4168-808f-8998435f7570.csv',
#  'Java2D_default_True_pyautogui_reader_19e31403-ab02-498c-bc74-d5e1187df383.csv',
#  'Java2D_rects_False_ctypes_reader_96d2f73c-8d72-40a2-bf59-9ba61ec82d6a.csv',
#  'Java2D_rects_False_pyautogui_reader_c8a8b9cd-86f9-48bf-879c-eefd1122eb26.csv',
#  'Java2D_rects_True_ctypes_reader_7f1b3e0e-ded6-4fd1-8d80-6b5d6c70f872.csv',
#  'Java2D_rects_True_pyautogui_reader_ae17d298-ca82-4b70-b56e-05ac307ee675.csv',
#  'JavaSwing_default_False_ctypes_reader_82f37c6c-9f2e-4b08-9c5c-e521f10af51b.csv',
#  'JavaSwing_default_False_pyautogui_reader_9c81a633-6e6b-4a84-bcb4-79b815db98a0.csv',
#  'JavaSwing_default_True_ctypes_reader_633cacac-e6f3-445e-881f-4c894da4e231.csv',
#  'JavaSwing_default_True_pyautogui_reader_08b3198c-bac6-4e4e-88e4-58f9af42ed2e.csv',
#  'JavaSwing_rects_False_ctypes_reader_96265fe2-a689-42ab-8684-595129d5bc05.csv',
#  'JavaSwing_rects_False_pyautogui_reader_af668242-1b57-4670-89e5-734d668a6386.csv',
#  'JavaSwing_rects_True_ctypes_reader_0e92d712-f90c-4a63-a0b3-0dbf5a592e96.csv',
#  'JavaSwing_rects_True_pyautogui_reader_e3bb85d3-38de-4f16-b702-baab27367782.csv',
#  'pygame_default_False_ctypes_reader_e10c2474-1fdc-4894-ad7b-44f925d7dfb0.csv',
#  'pygame_default_False_pyautogui_reader_c69cc118-7eb6-4d47-bd4a-ec948c693050.csv',
#  'pygame_default_True_ctypes_reader_dcd36449-d4c8-4640-bb15-de039b9437b9.csv',
#  'pygame_default_True_pyautogui_reader_ac221d6c-b30e-4c7c-b407-6e43b312e6a6.csv',
#  'pygame_rects_False_ctypes_reader_f14e500e-9b14-4427-999f-55b7f740f876.csv',
#  'pygame_rects_False_pyautogui_reader_2ad8e3e7-5479-4ac7-b0be-36de8e3f7111.csv',
#  'pygame_rects_True_ctypes_reader_09d15548-7724-447b-8721-8c5df563a748.csv',
#  'pygame_rects_True_pyautogui_reader_f867ecfa-e565-413f-8202-3be4af5a6539.csv',
#  'pyglet_default_False_ctypes_reader_73fb89f1-7030-438e-be8b-c904da2611ca.csv',
#  'pyglet_default_False_pyautogui_reader_5e50dafa-2c75-4f7e-a18b-f0b84ef5474e.csv',
#  'pyglet_default_True_ctypes_reader_44599824-ecdb-42f0-9e27-485e584c5b48.csv',
#  'pyglet_default_True_pyautogui_reader_ffa10c62-9d9f-46ee-b4b0-1e96607d8922.csv',
#  'pyglet_rects_False_ctypes_reader_3f24200f-d816-4131-8179-e457e6758d2e.csv',
#  'pyglet_rects_False_pyautogui_reader_4f2e6e5d-06ea-429e-a8ce-3f35a31d8437.csv',
#  'pyglet_rects_True_ctypes_reader_6cb1c6ef-af9c-4865-81b3-b70b98bd0641.csv',
#  'pyglet_rects_True_pyautogui_reader_f5e060ab-a41c-4dbb-aa00-4cb0b0dece28.csv',
#  'pyqt5_default_False_ctypes_reader_7e2ddbaf-7784-4832-86a1-ad47abb317c6.csv',
#  'pyqt5_default_False_pyautogui_reader_06b8f1b3-0fae-412a-9e9c-fbc7b407b211.csv',
#  'pyqt5_default_True_ctypes_reader_5835f6ca-67ad-4f98-aaa8-edd5ceef9728.csv',
#  'pyqt5_default_True_pyautogui_reader_cfbdd7b0-f736-4ca6-94db-07547b1a88ca.csv',
#  'pyqt5_rects_False_ctypes_reader_dad8a51b-4660-4c51-aed0-8913ccaa772c.csv',
#  'pyqt5_rects_False_pyautogui_reader_96b602d8-cab5-4030-a0ce-e1d010478f60.csv',
#  'pyqt5_rects_True_ctypes_reader_d01bdd9c-5ee3-4570-9381-7fd902d9e9c1.csv',
#  'pyqt5_rects_True_pyautogui_reader_de082338-ee28-4f18-a8fc-86a3293e1e7d.csv',
#  'pyqt6_default_False_ctypes_reader_3754a12a-46be-4beb-a04d-4295259799f4.csv',
#  'pyqt6_default_False_pyautogui_reader_fc8fc742-8766-4af1-ae8c-222484d9e02e.csv',
#  'pyqt6_default_True_ctypes_reader_66d0e8cb-bfc2-4a83-87bc-bdcf698a5695.csv',
#  'pyqt6_default_True_pyautogui_reader_850752c4-e936-404f-921a-731f08d6816d.csv',
#  'pyqt6_rects_False_ctypes_reader_4ded35ae-c412-4bd8-b28b-f6d7319fbaf6.csv',
#  'pyqt6_rects_False_pyautogui_reader_140dfccc-5724-4d09-98f4-f7c06ce0bdf8.csv',
#  'pyqt6_rects_True_ctypes_reader_99375a1e-5578-4529-9384-6b8a1b3b8a8e.csv',
#  'pyqt6_rects_True_pyautogui_reader_ddcff222-ce90-43b0-964e-27f8c1267bc3.csv',
#  'tkinter_default_False_ctypes_reader_c5656d3b-5368-4db2-b707-139747da539a.csv',
#  'tkinter_default_False_pyautogui_reader_f417d451-c621-4b08-8e7b-3c1e7732abe0.csv',
#  'tkinter_default_True_ctypes_reader_3e68b381-0f69-41e1-850e-76397df148e0.csv',
#  'tkinter_default_True_pyautogui_reader_3d29a813-726b-4c6b-b365-144f036f4fae.csv',
#  'tkinter_rects_False_ctypes_reader_2ae3f5ae-6c07-46be-a62e-03f823d1b831.csv',
#  'tkinter_rects_False_pyautogui_reader_14254084-0746-44e6-beda-60714cba7f1d.csv',
#  'tkinter_rects_True_ctypes_reader_c01475f7-736d-4989-9182-f30ba0b6113b.csv',
#  'tkinter_rects_True_pyautogui_reader_989a730d-3756-43f7-ba6e-69f30412bd24.csv']

# %%
dataframes = []
for file in files:
    dataframes.append(pd.read_csv(f"{PATH}/{file}"))
data_raw = pd.concat(dataframes)

# %%
#clean because windup not working with opengl based
#df.loc[~((df['col1'] == 'A') & (df['col2'] > 6))] 
# data_clean = data_raw.loc[~((data_raw['fw_running'] == True) & (data_raw['fw'] == -1) & (data_raw['diff'] < 0))]
# data = data_clean

# %%
data = data_raw

# %% [markdown]
# ## End-to-end latencies with and without running framework tester
# ### Complexity: Default
#
# about 5ms difference
# with running fw testerm it's faster

# %%
sns.set(rc={'figure.figsize':(15, 8)})
sns.boxplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running').set_title('end-to-end latencies with/without running fw-tester: default')
sns.stripplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
# ax = plt.gca()
# ax.set_ylim(0, 50000)
# for i in range(0, 20):
#     plt.axhline(i*2.1*1000, color='red')
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_9372\2995994967.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['complexity'] == 'default'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
# <Axes: title={'center': 'end-to-end latencies with/without running fw-tester: default'}, xlabel='program', ylabel='ete'>

# %% [markdown]
# ### Complexity: Rects
#
# Again, about 5ms difference
# Faster with running fw tester

# %%
sns.boxplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running').set_title('end-to-end latencies with/without running fw-tester')
sns.stripplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
# ax = plt.gca()
# ax.set_ylim(0, 40000)
# for i in range(0, 20):
#     plt.axhline(i*2.1*1000, color='red')
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_9372\3400025921.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['complexity'] == 'rects'], x='program', y='ete', hue='fw_running', dodge=True, color='black')
# <Axes: title={'center': 'end-to-end latencies with/without running fw-tester'}, xlabel='program', ylabel='ete'>

# %% [markdown]
# ## Framework latency by framework
# ### Complexity: Default
#
# windup unrealistisch große werte(?)

# %%
sns.boxplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# ax = plt.gca()
# ax.set_ylim(-100000, 2000000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_9372\2579862291.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['complexity'] == 'default') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# <Axes: xlabel='framework', ylabel='fw'>

# %% [markdown]
# ### Complexity: Rects
# was soll das denn???

# %%
sns.boxplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# ax = plt.gca()
# ax.set_ylim(-1000, 30000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_9372\2532508427.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['complexity'] == 'rects') & (data['fw_running'] == True))], x='framework', y='fw', hue='program', dodge=True, color='black')
# <Axes: xlabel='framework', ylabel='fw'>

# %% [markdown]
# ### Framework latency by complexity

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True, color='black')
# ax = plt.gca()
# ax.set_ylim(-1000, 30000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_9372\2864254672.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='complexity', y='fw', hue='program_fwrunning', dodge=True, color='black')
# <Axes: xlabel='complexity', ylabel='fw'>

# %% [markdown]
# ### Framework latency by framework

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True, color=(0,0,0))
# ax = plt.gca()
# ax.set_ylim(-1000, 30000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_9372\2863961882.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:#000000'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='framework', y='fw', hue='framework_complexity', dodge=True, color=(0,0,0))
# <Axes: xlabel='framework', ylabel='fw'>

# %%
sns.boxplot(data=data[data['fw_running'] == True], x='framework_complexity', y='fw', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[data['fw_running'] == True], x='framework_complexity', y='fw', hue='program', dodge=True, color='black')
# ax = plt.gca()
# ax.set_ylim(-1000, 15000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_9372\660076022.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[data['fw_running'] == True], x='framework_complexity', y='fw', hue='program', dodge=True, color='black')
# <Axes: xlabel='framework_complexity', ylabel='fw'>

# %% [markdown]
# ## Difference (ete and fw) by program
# ### Complexity: Rects

# %%
sns.boxplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True, color='black')
# ax = plt.gca()
# ax.set_ylim(-1000, 20000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_9372\2339582225.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'rects'))], x='framework', y='diff', hue='program', dodge=True, color='black')
# <Axes: xlabel='framework', ylabel='diff'>

# %% [markdown]
# ### Complexity: Default

# %%
sns.set(rc={'figure.figsize':(13.7,8.27)})
sns.boxplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True).set_title('')
sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True, color='black')
# ax = plt.gca()
# ax.set_ylim(-100000, 50000)
# Out:
# C:\Users\tina\AppData\Local\Temp\ipykernel_9372\2791981194.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(data=data[((data['fw_running'] == True) & (data['complexity'] == 'default'))], x='framework', y='diff', hue='program', dodge=True, color='black')
# <Axes: xlabel='framework', ylabel='diff'>

# %%
sns.boxplot(data=data[(data['fw_running'] == True)], x='framework', y='diff', hue='complexity', dodge=True).set_title('')
sns.stripplot(data=data[(data['fw_running'] == True)], x='framework', y='diff', hue='complexity', dodge=True)
# ax = plt.gca()
# ax.set_ylim(-10000, 40000)
# for i in range(0, 20):
#     plt.axhline(i*2.1*1000, color='red')
# Out:
# <Axes: xlabel='framework', ylabel='diff'>
